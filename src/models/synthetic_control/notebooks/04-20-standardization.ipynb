# %%
# %load_ext autoreload
# %autoreload complete

# %%
from src.models.synthetic_region.hyperopt import get_study_df

df = get_study_df("standardization")
df[
    [
        "method",
        "normalize",
        "mse_mean",
        "mse_std",
        "random_post_diff_mean_week_1",
        "random_post_diff_mean",
        "protest_post_diff_mean_week_1",
        "protest_post_diff_mean",
    ]
].sort_values("mse_mean")
# Out:
#               method  ...  protest_post_diff_mean
# 0  linear_regression  ...                0.000000
# 1  linear_regression  ...                0.000000
# 2               mean  ...                0.000000
# 3               mean  ...                0.002514
#
# [4 rows x 8 columns]

# %%
from src.models.synthetic_region.hyperopt import get_study_df

study_df = get_study_df("standardization_v1")
study_df[
    [
        "method",
        "normalize",
        "mse_mean",
        "mse_std",
        "random_post_diff_mean_week_1",
        "random_post_diff_mean",
        "protest_post_diff_mean_week_1",
        "protest_post_diff_mean",
    ]
].sort_values("mse_mean")
# Out:
#                method  ...  protest_post_diff_mean
# 13               mean  ...                0.013850
# 1   linear_regression  ...               -0.007273
# 22               mean  ...                0.002514
# 26               mean  ...                0.002514
# 24               mean  ...                0.002514
# 18               mean  ...                0.002514
# 19               mean  ...                0.002514
# 21               mean  ...                0.002514
# 28               mean  ...                0.013850
# 0                mean  ...                0.013850
# 15              ridge  ...               -0.010570
# 29              ridge  ...               -0.010570
# 11              ridge  ...               -0.012048
# 31              ridge  ...               -0.012048
# 12      random_forest  ...                0.043505
# 30      random_forest  ...                0.043505
# 33      random_forest  ...                0.043505
# ...

# %%
from src.data.discourse.visual import plot_comparison

df = pd.DataFrame(study_df["agg_df_protest"].iloc[1])
plot_comparison(df)
# Out:
# <Axes: >
