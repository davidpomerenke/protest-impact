# %%
# %load_ext autoreload
# %autoreload complete

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from matplotlib_inline.backend_inline import set_matplotlib_formats
from tqdm.notebook import tqdm

set_matplotlib_formats("svg")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.paths import external_data

path = external_data / "ids-dereko"
df = pd.read_csv(path / "corpora/corpora.csv", sep=";")
df
# Out:
#     Corpus    Sigle                         Titel  von_  bis_   von   bis  \
# 0       W1      bmp           Berliner Morgenpost   NaN   NaN  1997  2022
# 1       W1      brz        Braunschweiger Zeitung   NaN   NaN  2005  2013
# 2       W1      bvz  Burgenländische Volkszeitung   NaN   NaN  2007  2015
# 3       W1  bzt-pub              Berliner Zeitung   NaN   NaN  2009  2022
# 4       W1      dpr                    Die Presse   NaN   NaN  1991  2022
# ..     ...      ...                           ...   ...   ...   ...   ...
# 174     W4      wiz                Wiener Zeitung   NaN   NaN  2000  2022
# 175     W4      wku            Wiesbadener Kurier   NaN   NaN  2000  2022
# 176     W4      wtb          Wiesbadener Tagblatt   NaN   NaN  2002  2019
# 177     W4      wbl              WirtschaftsBlatt   NaN   NaN  2000  2016
# 178     W4      wor               Wormser Zeitung   NaN   NaN  2002  2022
#
#      Lizenz         Stadt Region National  Leitmedium
# ...

# %%
print(len(df))
df = df[df["bis"] == 2022]
print(len(df))
df = df[~df["Region"].isin(["AT", "CH"]) & ~df["National"].isin(["AT", "CH"])]
print(len(df))
print(len(df[df["National"] == "DE"]))
print(len(df[~df["Region"].isna()]))
# Out:
# 179
# 154
# 121
# 15
# 106

# %%
df["Region"].value_counts()
# Out:
# BY    17
# HE    17
# NW    16
# BW    13
# NI     7
# RP     6
# SN     6
# BB     5
# BE     4
# TH     4
# HH     3
# MV     3
# ST     2
# SH     2
# SL     1
# Name: Region, dtype: int64
