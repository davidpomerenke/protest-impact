# %%
# %load_ext autoreload
# %autoreload complete

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from matplotlib_inline.backend_inline import set_matplotlib_formats
from tqdm.notebook import tqdm

from src.cache import cache

set_matplotlib_formats("svg")

# %% [markdown]
# - Login first and manually select:
#   - In the search interface:
#     - Interpret spaces as word distance of 1, rather than OR operator
#   - In the settings, under the heading _Ergebnisse_ (results):
#     - Daily counts as the primary _results_ page (_not_ the primary _corpus representation_ page, which is irrelevant)
#     - Page limit = 20_000 or so
#     - Sort by date
# - Then close the browser and it should be saved via the cookies, which the script will reuse
# - Reuse the same cookie session as much as possible, otherwise rate limiting issues arise
# - Scrape at night or on the weekend, it is a huge performance difference for searching in the database

# %%
from src.data.news.dereko.scraping import prepare, start

page, browser, context = await start(headless=False)
page, browser = await prepare(page, browser, context)

# %%
corpora = pd.read_csv(
    project_root / "data/ids-dereko/corpora/dereko_corpora.csv", delimiter=";"
)
# corpora["bis"] = corpora["bis"].fillna(0).astype(int)
corpora["bis_"] = corpora["bis_"].fillna(0).astype(int)
corpora = corpora[(corpora["bis"] == "2022") | (corpora["bis_"] == 2022)]
corpora
# Out:
#     Corpus    Sigle                 Titel    von_  bis_   von     bis Lizenz  \
# 1       W1      bmp   Berliner Morgenpost  1997.0  2022   NaN  Berlin     BE
# 4       W1  bzt-pub      Berliner Zeitung  2009.0  2022   NaN  Berlin     BE
# 5       W1      dpr            Die Presse  1991.0  2022   NaN     NaN    NaN
# 6       W1      flt                Falter  2000.0  2022   NaN     NaN    NaN
# 7       W1      foc                 FOCUS  2000.0  2022   NaN  Berlin     BE
# ..     ...      ...                   ...     ...   ...   ...     ...    ...
# 180     W4      wez  Westdeutsche Zeitung     NaN     0  2009    2022    NaN
# 181     W4      wfb       Westfalen-Blatt  2010.0  2015  2018    2022    NaN
# 182     W4      wiz        Wiener Zeitung     NaN     0  2000    2022    NaN
# 183     W4      wku    Wiesbadener Kurier     NaN     0  2000    2022    NaN
# 186     W4      wor       Wormser Zeitung     NaN     0  2002    2022    NaN
#
#          Stadt Region National  Leitmedium
# 1          NaN    NaN      NaN         NaN
# 4          NaN    NaN      NaN         NaN
# 5           AT    NaN      NaN         NaN
# 6           AT    NaN      NaN         NaN
# 7           DE    NaN      NaN         NaN
# ..         ...    ...      ...         ...
# 180  Wuppertal     NW      NaN         NaN
# 181  Bielefeld     NW      NaN         NaN
# 182        NaN    NaN      NaN         NaN
# 183  Wiesbaden     HE      NaN         NaN
# 186      Worms     RP      NaN         NaN
#
# [157 rows x 12 columns]

# %%
from time import time

from src.data.news.dereko.scraping import scrape_count_table

for type_ in ["subsidiary_goal", "framing", "goal", "protest", "not_protest"]:
    for corpus, code, title in tqdm(corpora[["Corpus", "Sigle", "Titel"]].values):
        print(corpus, code, title, end="\t\t")
        t0 = time()
        await scrape_count_table(corpus, code, title, type_, headless=False)
        print(f"{time() - t0:.2f} sec")
# Out:
#   0%|          | 0/157 [00:00<?, ?it/s]
# W1 bmp Berliner Morgenpost		0.01 sec
# W1 bzt-pub Berliner Zeitung		0.00 sec
# W1 dpr Die Presse		0.01 sec
# W1 flt Falter		0.00 sec
# W1 foc FOCUS		0.00 sec
# W1 haz Hannoversche Allgemeine		0.00 sec
# W1 hmp Hamburger Morgenpost		0.00 sec
# W1 mm Mannheimer Morgen		0.00 sec
# W1 news NEWS		0.00 sec
# W1 nku Nordkurier		0.00 sec
# W1 non Niederösterreichische Nachrichten		0.00 sec
# W1 nun Nürnberger Nachrichten		0.00 sec
# W1 nuz Nürnberger Zeitung		0.01 sec
# W1 nzs NZZ am Sonntag		0.00 sec
# W1 nzz Neue Zürcher Zeitung		0.00 sec
# W1 prf profil		0.00 sec
# W1 rhz Rhein-Zeitung		0.00 sec
# W1 sbl Sonntagsblick		0.00 sec
# W1 sgt St. Galler Tagblatt		0.00 sec
# W1 spiegel Der Spiegel		0.00 sec
# W1 ste Stern		0.00 sec
# W1 sz Süddeutsche Zeitung		0.00 sec
# W1 tas SonntagsZeitung (Tages-Anzeiger)		0.00 sec
# W1 taz-pub die tageszeitung		0.00 sec
# W1 wwo Weltwoche		0.00 sec
# W1 zeit Die Zeit		0.00 sec
# W1 zta Tages-Anzeiger		0.00 sec
# W2 aan Aachener Nachrichten		0.00 sec
# W2 aaz Aachener Zeitung		0.00 sec
# W2 abo Aar-Bote		0.00 sec
# W2 alz Aller-Zeitung		0.00 sec
# W2 azm Abendzeitung		0.00 sec
# W2 baz Basler Zeitung		0.00 sec
# W2 bdz Badische Zeitung		0.00 sec
# W2 bez Berner Zeitung		0.00 sec
# W2 bku Berliner Kurier		0.00 sec
# W2 bli Blick		0.00 sec
# W2 boz Börsen-Zeitung		0.00 sec
# W2 bru Bayerische Rundschau		0.00 sec
# W2 bze B.Z.		0.00 sec
# W2 bun Der Bund		0.00 sec
# W2 bwa Braunauer Warte am Inn		0.00 sec
# W2 ctb Coburger Tageblatt		0.00 sec
# W2 dak Die Aktuelle		0.00 sec
# W2 daz Döbelner Allgemeine Zeitung		0.00 sec
# W2 dec Darmstädter Echo		0.00 sec
# W2 dki Die Kitzinger		0.00 sec
# W2 dnn Dresdner Neueste Nachrichten		0.00 sec
# W2 dol Dolomiten		0.00 sec
# W2 dpr Der Prignitzer		0.00 sec
# W2 eft Eichsfelder Tageblatt		0.00 sec
# W2 fnp Frankfurter Neue Presse		0.00 sec
# W2 frt Fränkischer Tag		0.00 sec
# W2 gaz General-Anzeiger Bonn		0.00 sec
# W2 gta Göttinger Tageblatt		0.00 sec
# W2 hab Handelsblatt		0.00 sec
# W2 hfz Hofheimer Zeitung		0.00 sec
# W2 hhz Hochheimer Zeitung		0.00 sec
# W2 hkr Höchster Kreisblatt		0.00 sec
# W2 hst Heilbronner Stimme		0.00 sec
# W2 htb Hohenloher Tagblatt		0.00 sec
# W2 hzz Hohenzollerische Zeitung		0.00 sec
# W2 kaz Kreis-Anzeiger		0.00 sec
# W2 klz Kleine Zeitung		0.00 sec
# W2 ksa Kölner-Stadtanzeiger		0.00 sec
# W2 kur Kurier (Österreich)		0.00 sec
# W2 lan Lauterbacher Anzeiger		0.00 sec
# W2 laz Lampertheimer Zeitung		0.00 sec
# W2 lru Lausitzer Rundschau		0.00 sec
# W2 msp Main-Spitze		0.00 sec
# W2 noz Neue Osnabrücker Zeitung		0.00 sec
# W2 nwt Neue Welt		0.00 sec
# W2 osz Ostsee-Zeitung		0.00 sec
# W2 paz Peiner Allgemeine Zeitung		0.00 sec
# W2 stb Straubinger Tagblatt		12.24 sec
# W2 tvd TV Digital		0.00 sec
# W2 vbw Volksblatt		0.00 sec
# W2 vzs Schweinfurter Volkszeitung		0.00 sec
# W2 w Die Welt		0.00 sec
# W2 was Welt am Sonntag		0.00 sec
# W3 beo Berner Oberländer		0.00 sec
# W3 bmo Bergische Morgenpost		0.00 sec
# W3 bue Bürstädter Zeitung		0.00 sec
# W3 bzg Bergedorfer Zeitung		0.00 sec
# W3 dgl Die Glocke		0.00 sec
# W3 hna Hessische Niedersächsische Allgemeine		0.00 sec
# W3 hat Haller Tagblatt		0.00 sec
# W3 jue Jüdische Allgemeine		0.00 sec
# W3 kir Kirner Zeitung		0.00 sec
# W3 kn Kieler Nachrichten		0.00 sec
# W3 kru Kölnische Rundschau		0.00 sec
# W3 kxp Kölner Express		0.00 sec
# W3 lhz Landhuter Zeitung		0.00 sec
# W3 ln Lübecker Nachrichten		0.00 sec
# W3 lvz Leipziger-Volkszeitung		0.00 sec
# W3 mag Märkische Allgemeine		0.00 sec
# W3 maz Allgemeine Zeitung		0.00 sec
# W3 mme Münchner Merkur		0.00 sec
# W3 mpo Main-Post		0.00 sec
# W3 muv Metzinger Uracher Volksblatt		0.00 sec
# W3 mze Mitteldeutsche Zeitung		0.00 sec
# W3 nbk Nordbayerischer Kurier		0.00 sec
# W3 ngz Neuss-Grevenbroicher Zeitung		0.00 sec
# W3 nkz Neue Kronen-Zeitung		0.00 sec
# W3 nlz Neue Luzerner Zeitung		0.00 sec
# W3 nnn Norddeutsche Neueste Nachrichten		0.00 sec
# W3 nnp Nassauische Neue Presse		0.00 sec
# W3 now Nordwest-Zeitung		0.00 sec
# W3 npr Neue Presse		0.00 sec
# W3 nvb Neues Volksblatt		0.00 sec
# W3 nvt Neue Vorarlberger Tageszeitung		0.00 sec
# W3 nwe Neue Westfälische		0.00 sec
# W3 nws Die Nordwestschweiz		0.00 sec
# W3 nwz Neue Württembergische Zeitung		0.00 sec
# W3 oaz Oschatzer Allgemeine Zeitung		0.00 sec
# W3 ohz Oberhessische Zeitung		0.00 sec
# W3 ovz Osterländer Volkszeitung		0.00 sec
# W3 pnn Potsdamer Neuste Nachrichten		0.00 sec
# W3 pnp Passauer Neue Presse		0.00 sec
# W3 rln Reutlinger Nachrichten		0.00 sec
# W3 rn Ruhr Nachrichten		0.00 sec
# W3 rpo Rheinische Post		0.00 sec
# W3 rsw Rundschau für den Schwäbischen Wald		0.00 sec
# W3 rue Rüsselsheimer Echo		0.00 sec
# W3 sbn Salzburger Nachrichten		0.00 sec
# W3 smp Solinger Morgenpost		0.00 sec
# W4 sta Der Standard		0.00 sec
# W4 tsp Der Tagesspiegel		0.00 sec
# W4 fpc Freie Presse		0.00 sec
# W4 giz Giessener Anzeiger		0.00 sec
# W4 haa Hamburger Abendblatt		0.00 sec
# W4 hdz Handelszeitung		0.00 sec
# W4 mib Mittelbayerische Zeitung		0.00 sec
# W4 oon Oberösterreichische Nachrichten		0.00 sec
# W4 otz Ostthüringer Zeitung		0.00 sec
# W4 rga Reutlinger General-Anzeiger		0.00 sec
# W4 rvz Rieder Volkszeitung		0.00 sec
# W4 saz Saale-Zeitung		0.00 sec
# W4 sbz Saarbrücker Zeitung		0.00 sec
# W4 sze Sächsische Zeitung		0.00 sec
# W4 scz Schwäbische Zeitung		0.00 sec
# W4 sct Schweinfurter Tagblatt		0.00 sec
# W4 svz Schweriner Volkszeitung		0.00 sec
# W4 sku Südkurier		0.00 sec
# W4 swp Südwest Presse		0.00 sec
# W4 tnz Taunus Zeitung		0.00 sec
# W4 tha Thüringer Allgemeine		0.00 sec
# W4 tlz Thüringische Landeszeitung		0.00 sec
# W4 ttz Tiroler Tageszeitung		0.00 sec
# W4 tvf Trierischer Volksfreund		0.00 sec
# W4 uan Usinger Anzeiger		0.00 sec
# W4 van Vorarlberger Nachrichten		0.00 sec
# W4 wez Westdeutsche Zeitung		0.00 sec
# W4 wfb Westfalen-Blatt		0.00 sec
# W4 wiz Wiener Zeitung		0.00 sec
# W4 wku Wiesbadener Kurier		0.00 sec
# W4 wor Wormser Zeitung		0.00 sec
#   0%|          | 0/157 [00:00<?, ?it/s]
# W1 bmp Berliner Morgenpost		0.00 sec
# W1 bzt-pub Berliner Zeitung		0.00 sec
# W1 dpr Die Presse		0.00 sec
# W1 flt Falter		0.00 sec
# W1 foc FOCUS		0.00 sec
# W1 haz Hannoversche Allgemeine		0.00 sec
# W1 hmp Hamburger Morgenpost		0.00 sec
# W1 mm Mannheimer Morgen		0.00 sec
# W1 news NEWS		0.00 sec
# W1 nku Nordkurier		0.00 sec
# W1 non Niederösterreichische Nachrichten		0.00 sec
# W1 nun Nürnberger Nachrichten		0.00 sec
# W1 nuz Nürnberger Zeitung		0.00 sec
# W1 nzs NZZ am Sonntag		0.00 sec
# W1 nzz Neue Zürcher Zeitung		0.00 sec
# W1 prf profil		0.00 sec
# W1 rhz Rhein-Zeitung		0.00 sec
# W1 sbl Sonntagsblick		0.00 sec
# W1 sgt St. Galler Tagblatt		0.00 sec
# W1 spiegel Der Spiegel		0.00 sec
# W1 ste Stern		0.00 sec
# W1 sz Süddeutsche Zeitung		0.00 sec
# W1 tas SonntagsZeitung (Tages-Anzeiger)		0.00 sec
# W1 taz-pub die tageszeitung		0.00 sec
# W1 wwo Weltwoche		0.00 sec
# W1 zeit Die Zeit		0.00 sec
# W1 zta Tages-Anzeiger		0.00 sec
# W2 aan Aachener Nachrichten		0.00 sec
# W2 aaz Aachener Zeitung		0.00 sec
# W2 abo Aar-Bote		0.00 sec
# W2 alz Aller-Zeitung		13.40 sec
# W2 azm Abendzeitung		0.01 sec
# W2 baz Basler Zeitung		0.00 sec
# W2 bdz Badische Zeitung		0.00 sec
# W2 bez Berner Zeitung		0.00 sec
# W2 bku Berliner Kurier		0.00 sec
# W2 bli Blick		0.00 sec
# W2 boz Börsen-Zeitung		0.00 sec
# W2 bru Bayerische Rundschau		0.00 sec
# W2 bze B.Z.		0.00 sec
# W2 bun Der Bund		0.00 sec
# W2 bwa Braunauer Warte am Inn		0.00 sec
# W2 ctb Coburger Tageblatt		0.00 sec
# W2 dak Die Aktuelle		11.61 sec
# W2 daz Döbelner Allgemeine Zeitung		0.00 sec
# W2 dec Darmstädter Echo		0.00 sec
# W2 dki Die Kitzinger		0.00 sec
# W2 dnn Dresdner Neueste Nachrichten		0.00 sec
# W2 dol Dolomiten		0.00 sec
# W2 dpr Der Prignitzer		0.00 sec
# W2 eft Eichsfelder Tageblatt		0.00 sec
# W2 fnp Frankfurter Neue Presse		0.00 sec
# W2 frt Fränkischer Tag		0.00 sec
# W2 gaz General-Anzeiger Bonn		0.00 sec
# W2 gta Göttinger Tageblatt		0.00 sec
# W2 hab Handelsblatt		0.00 sec
# W2 hfz Hofheimer Zeitung		0.00 sec
# W2 hhz Hochheimer Zeitung		0.00 sec
# W2 hkr Höchster Kreisblatt		0.00 sec
# W2 hst Heilbronner Stimme		0.00 sec
# W2 htb Hohenloher Tagblatt		0.00 sec
# W2 hzz Hohenzollerische Zeitung		0.00 sec
# W2 kaz Kreis-Anzeiger		0.00 sec
# W2 klz Kleine Zeitung		0.00 sec
# W2 ksa Kölner-Stadtanzeiger		0.00 sec
# W2 kur Kurier (Österreich)		0.00 sec
# W2 lan Lauterbacher Anzeiger		0.00 sec
# W2 laz Lampertheimer Zeitung		0.00 sec
# W2 lru Lausitzer Rundschau		0.00 sec
# W2 msp Main-Spitze		0.00 sec
# W2 noz Neue Osnabrücker Zeitung		0.00 sec
# W2 nwt Neue Welt		10.41 sec
# W2 osz Ostsee-Zeitung		0.01 sec
# W2 paz Peiner Allgemeine Zeitung		0.00 sec
# W2 stb Straubinger Tagblatt		7.27 sec
# W2 tvd TV Digital		0.00 sec
# W2 vbw Volksblatt		0.00 sec
# W2 vzs Schweinfurter Volkszeitung		0.00 sec
# W2 w Die Welt		0.00 sec
# W2 was Welt am Sonntag		0.00 sec
# W3 beo Berner Oberländer		0.00 sec
# W3 bmo Bergische Morgenpost		0.00 sec
# W3 bue Bürstädter Zeitung		0.00 sec
# W3 bzg Bergedorfer Zeitung		0.00 sec
# W3 dgl Die Glocke		0.00 sec
# W3 hna Hessische Niedersächsische Allgemeine		0.00 sec
# W3 hat Haller Tagblatt		0.00 sec
# W3 jue Jüdische Allgemeine		0.00 sec
# W3 kir Kirner Zeitung		0.00 sec
# W3 kn Kieler Nachrichten		0.00 sec
# W3 kru Kölnische Rundschau		0.00 sec
# W3 kxp Kölner Express		0.00 sec
# W3 lhz Landhuter Zeitung		0.00 sec
# W3 ln Lübecker Nachrichten		0.00 sec
# W3 lvz Leipziger-Volkszeitung		0.00 sec
# W3 mag Märkische Allgemeine		0.00 sec
# W3 maz Allgemeine Zeitung		0.00 sec
# W3 mme Münchner Merkur		0.00 sec
# W3 mpo Main-Post		0.00 sec
# W3 muv Metzinger Uracher Volksblatt		0.00 sec
# W3 mze Mitteldeutsche Zeitung		0.00 sec
# W3 nbk Nordbayerischer Kurier		0.00 sec
# W3 ngz Neuss-Grevenbroicher Zeitung		0.00 sec
# W3 nkz Neue Kronen-Zeitung		0.00 sec
# W3 nlz Neue Luzerner Zeitung		0.00 sec
# W3 nnn Norddeutsche Neueste Nachrichten		0.00 sec
# W3 nnp Nassauische Neue Presse		0.00 sec
# W3 now Nordwest-Zeitung		0.00 sec
# W3 npr Neue Presse		0.00 sec
# W3 nvb Neues Volksblatt		0.00 sec
# W3 nvt Neue Vorarlberger Tageszeitung		0.00 sec
# W3 nwe Neue Westfälische		0.00 sec
# W3 nws Die Nordwestschweiz		0.00 sec
# W3 nwz Neue Württembergische Zeitung		0.00 sec
# W3 oaz Oschatzer Allgemeine Zeitung		0.00 sec
# W3 ohz Oberhessische Zeitung		0.00 sec
# W3 ovz Osterländer Volkszeitung		0.00 sec
# W3 pnn Potsdamer Neuste Nachrichten		0.00 sec
# W3 pnp Passauer Neue Presse		0.00 sec
# W3 rln Reutlinger Nachrichten		0.00 sec
# W3 rn Ruhr Nachrichten		0.00 sec
# W3 rpo Rheinische Post		0.00 sec
# W3 rsw Rundschau für den Schwäbischen Wald		0.00 sec
# W3 rue Rüsselsheimer Echo		0.00 sec
# W3 sbn Salzburger Nachrichten		0.00 sec
# W3 smp Solinger Morgenpost		0.00 sec
# W4 sta Der Standard		0.00 sec
# W4 tsp Der Tagesspiegel		0.00 sec
# W4 fpc Freie Presse		0.00 sec
# W4 giz Giessener Anzeiger		0.00 sec
# W4 haa Hamburger Abendblatt		0.00 sec
# W4 hdz Handelszeitung		0.00 sec
# W4 mib Mittelbayerische Zeitung		0.00 sec
# W4 oon Oberösterreichische Nachrichten		0.00 sec
# W4 otz Ostthüringer Zeitung		0.00 sec
# W4 rga Reutlinger General-Anzeiger		0.00 sec
# W4 rvz Rieder Volkszeitung		0.00 sec
# W4 saz Saale-Zeitung		0.00 sec
# W4 sbz Saarbrücker Zeitung		0.00 sec
# W4 sze Sächsische Zeitung		0.00 sec
# W4 scz Schwäbische Zeitung		0.00 sec
# W4 sct Schweinfurter Tagblatt		0.00 sec
# W4 svz Schweriner Volkszeitung		0.00 sec
# W4 sku Südkurier		0.00 sec
# W4 swp Südwest Presse		0.00 sec
# W4 tnz Taunus Zeitung		0.00 sec
# W4 tha Thüringer Allgemeine		0.00 sec
# W4 tlz Thüringische Landeszeitung		0.00 sec
# W4 ttz Tiroler Tageszeitung		0.00 sec
# W4 tvf Trierischer Volksfreund		0.00 sec
# W4 uan Usinger Anzeiger		0.00 sec
# W4 van Vorarlberger Nachrichten		0.00 sec
# W4 wez Westdeutsche Zeitung		0.00 sec
# W4 wfb Westfalen-Blatt		0.00 sec
# W4 wiz Wiener Zeitung		0.00 sec
# W4 wku Wiesbadener Kurier		0.00 sec
# W4 wor Wormser Zeitung		0.00 sec
#   0%|          | 0/157 [00:00<?, ?it/s]
# W1 bmp Berliner Morgenpost		0.00 sec
# W1 bzt-pub Berliner Zeitung		0.00 sec
# W1 dpr Die Presse		0.00 sec
# W1 flt Falter		0.00 sec
# W1 foc FOCUS		0.00 sec
# W1 haz Hannoversche Allgemeine		0.00 sec
# W1 hmp Hamburger Morgenpost		0.00 sec
# W1 mm Mannheimer Morgen		0.00 sec
# W1 news NEWS		0.00 sec
# W1 nku Nordkurier		0.00 sec
# W1 non Niederösterreichische Nachrichten		0.00 sec
# W1 nun Nürnberger Nachrichten		0.00 sec
# W1 nuz Nürnberger Zeitung		0.00 sec
# W1 nzs NZZ am Sonntag		0.00 sec
# W1 nzz Neue Zürcher Zeitung		0.00 sec
# W1 prf profil		0.00 sec
# W1 rhz Rhein-Zeitung		0.00 sec
# W1 sbl Sonntagsblick		0.00 sec
# W1 sgt St. Galler Tagblatt		0.00 sec
# W1 spiegel Der Spiegel		0.00 sec
# W1 ste Stern		0.00 sec
# W1 sz Süddeutsche Zeitung		0.00 sec
# W1 tas SonntagsZeitung (Tages-Anzeiger)		0.00 sec
# W1 taz-pub die tageszeitung		0.00 sec
# W1 wwo Weltwoche		0.00 sec
# W1 zeit Die Zeit		0.00 sec
# W1 zta Tages-Anzeiger		0.00 sec
# W2 aan Aachener Nachrichten		0.00 sec
# W2 aaz Aachener Zeitung		0.00 sec
# W2 abo Aar-Bote		0.00 sec
# W2 alz Aller-Zeitung		11.04 sec
# W2 azm Abendzeitung		0.00 sec
# W2 baz Basler Zeitung		0.00 sec
# W2 bdz Badische Zeitung		0.00 sec
# W2 bez Berner Zeitung		0.00 sec
# W2 bku Berliner Kurier		0.00 sec
# W2 bli Blick		0.00 sec
# W2 boz Börsen-Zeitung		0.00 sec
# W2 bru Bayerische Rundschau		0.00 sec
# W2 bze B.Z.		0.00 sec
# W2 bun Der Bund		0.00 sec
# W2 bwa Braunauer Warte am Inn		0.00 sec
# W2 ctb Coburger Tageblatt		0.00 sec
# W2 dak Die Aktuelle		0.00 sec
# W2 daz Döbelner Allgemeine Zeitung		0.00 sec
# W2 dec Darmstädter Echo		0.00 sec
# W2 dki Die Kitzinger		0.00 sec
# W2 dnn Dresdner Neueste Nachrichten		0.00 sec
# W2 dol Dolomiten		0.00 sec
# W2 dpr Der Prignitzer		0.00 sec
# W2 eft Eichsfelder Tageblatt		0.00 sec
# W2 fnp Frankfurter Neue Presse		0.00 sec
# W2 frt Fränkischer Tag		0.00 sec
# W2 gaz General-Anzeiger Bonn		0.00 sec
# W2 gta Göttinger Tageblatt		0.00 sec
# W2 hab Handelsblatt		0.00 sec
# W2 hfz Hofheimer Zeitung		0.00 sec
# W2 hhz Hochheimer Zeitung		0.00 sec
# W2 hkr Höchster Kreisblatt		0.00 sec
# W2 hst Heilbronner Stimme		0.00 sec
# W2 htb Hohenloher Tagblatt		0.00 sec
# W2 hzz Hohenzollerische Zeitung		0.00 sec
# W2 kaz Kreis-Anzeiger		0.00 sec
# W2 klz Kleine Zeitung		0.00 sec
# W2 ksa Kölner-Stadtanzeiger		0.00 sec
# W2 kur Kurier (Österreich)		0.00 sec
# W2 lan Lauterbacher Anzeiger		0.00 sec
# W2 laz Lampertheimer Zeitung		0.00 sec
# W2 lru Lausitzer Rundschau		0.00 sec
# W2 msp Main-Spitze		0.00 sec
# W2 noz Neue Osnabrücker Zeitung		0.00 sec
# W2 nwt Neue Welt		0.00 sec
# W2 osz Ostsee-Zeitung		0.00 sec
# W2 paz Peiner Allgemeine Zeitung		0.00 sec
# W2 stb Straubinger Tagblatt		8.51 sec
# W2 tvd TV Digital		0.00 sec
# W2 vbw Volksblatt		0.00 sec
# W2 vzs Schweinfurter Volkszeitung		0.00 sec
# W2 w Die Welt		0.00 sec
# W2 was Welt am Sonntag		0.00 sec
# W3 beo Berner Oberländer		0.00 sec
# W3 bmo Bergische Morgenpost		0.00 sec
# W3 bue Bürstädter Zeitung		0.00 sec
# W3 bzg Bergedorfer Zeitung		0.00 sec
# W3 dgl Die Glocke		0.00 sec
# W3 hna Hessische Niedersächsische Allgemeine		0.00 sec
# W3 hat Haller Tagblatt		0.00 sec
# W3 jue Jüdische Allgemeine		0.00 sec
# W3 kir Kirner Zeitung		0.00 sec
# W3 kn Kieler Nachrichten		0.00 sec
# W3 kru Kölnische Rundschau		0.00 sec
# W3 kxp Kölner Express		0.00 sec
# W3 lhz Landhuter Zeitung		0.00 sec
# W3 ln Lübecker Nachrichten		0.00 sec
# W3 lvz Leipziger-Volkszeitung		0.00 sec
# W3 mag Märkische Allgemeine		0.00 sec
# W3 maz Allgemeine Zeitung		0.00 sec
# W3 mme Münchner Merkur		0.00 sec
# W3 mpo Main-Post		0.00 sec
# W3 muv Metzinger Uracher Volksblatt		0.00 sec
# W3 mze Mitteldeutsche Zeitung		0.00 sec
# W3 nbk Nordbayerischer Kurier		0.00 sec
# W3 ngz Neuss-Grevenbroicher Zeitung		0.00 sec
# W3 nkz Neue Kronen-Zeitung		0.00 sec
# W3 nlz Neue Luzerner Zeitung		0.00 sec
# W3 nnn Norddeutsche Neueste Nachrichten		0.00 sec
# W3 nnp Nassauische Neue Presse		0.00 sec
# W3 now Nordwest-Zeitung		0.00 sec
# W3 npr Neue Presse		0.00 sec
# W3 nvb Neues Volksblatt		0.00 sec
# W3 nvt Neue Vorarlberger Tageszeitung		0.00 sec
# W3 nwe Neue Westfälische		0.00 sec
# W3 nws Die Nordwestschweiz		0.00 sec
# W3 nwz Neue Württembergische Zeitung		0.00 sec
# W3 oaz Oschatzer Allgemeine Zeitung		0.00 sec
# W3 ohz Oberhessische Zeitung		0.00 sec
# W3 ovz Osterländer Volkszeitung		0.00 sec
# W3 pnn Potsdamer Neuste Nachrichten		0.00 sec
# W3 pnp Passauer Neue Presse		0.00 sec
# W3 rln Reutlinger Nachrichten		0.00 sec
# W3 rn Ruhr Nachrichten		0.00 sec
# W3 rpo Rheinische Post		0.00 sec
# W3 rsw Rundschau für den Schwäbischen Wald		0.00 sec
# W3 rue Rüsselsheimer Echo		0.00 sec
# W3 sbn Salzburger Nachrichten		0.00 sec
# W3 smp Solinger Morgenpost		0.00 sec
# W4 sta Der Standard		0.00 sec
# W4 tsp Der Tagesspiegel		0.00 sec
# W4 fpc Freie Presse		0.00 sec
# W4 giz Giessener Anzeiger		0.00 sec
# W4 haa Hamburger Abendblatt		0.00 sec
# W4 hdz Handelszeitung		0.00 sec
# W4 mib Mittelbayerische Zeitung		0.00 sec
# W4 oon Oberösterreichische Nachrichten		0.00 sec
# W4 otz Ostthüringer Zeitung		0.00 sec
# W4 rga Reutlinger General-Anzeiger		0.00 sec
# W4 rvz Rieder Volkszeitung		0.00 sec
# W4 saz Saale-Zeitung		0.00 sec
# W4 sbz Saarbrücker Zeitung		0.00 sec
# W4 sze Sächsische Zeitung		0.00 sec
# W4 scz Schwäbische Zeitung		0.00 sec
# W4 sct Schweinfurter Tagblatt		0.00 sec
# W4 svz Schweriner Volkszeitung		0.00 sec
# W4 sku Südkurier		0.00 sec
# W4 swp Südwest Presse		0.00 sec
# W4 tnz Taunus Zeitung		0.00 sec
# W4 tha Thüringer Allgemeine		0.00 sec
# W4 tlz Thüringische Landeszeitung		0.00 sec
# W4 ttz Tiroler Tageszeitung		0.00 sec
# W4 tvf Trierischer Volksfreund		0.00 sec
# W4 uan Usinger Anzeiger		0.00 sec
# W4 van Vorarlberger Nachrichten		0.00 sec
# W4 wez Westdeutsche Zeitung		0.00 sec
# W4 wfb Westfalen-Blatt		0.00 sec
# W4 wiz Wiener Zeitung		0.00 sec
# W4 wku Wiesbadener Kurier		0.00 sec
# W4 wor Wormser Zeitung		0.00 sec
#   0%|          | 0/157 [00:00<?, ?it/s]
# W1 bmp Berliner Morgenpost		0.00 sec
# W1 bzt-pub Berliner Zeitung		0.00 sec
# W1 dpr Die Presse		0.00 sec
# W1 flt Falter		0.00 sec
# W1 foc FOCUS		0.00 sec
# W1 haz Hannoversche Allgemeine		0.00 sec
# W1 hmp Hamburger Morgenpost		0.00 sec
# W1 mm Mannheimer Morgen		0.00 sec
# W1 news NEWS		0.00 sec
# W1 nku Nordkurier		0.00 sec
# W1 non Niederösterreichische Nachrichten		0.00 sec
# W1 nun Nürnberger Nachrichten		0.00 sec
# W1 nuz Nürnberger Zeitung		0.00 sec
# W1 nzs NZZ am Sonntag		0.00 sec
# W1 nzz Neue Zürcher Zeitung		0.00 sec
# W1 prf profil		0.00 sec
# W1 rhz Rhein-Zeitung		0.00 sec
# W1 sbl Sonntagsblick		0.00 sec
# W1 sgt St. Galler Tagblatt		0.00 sec
# W1 spiegel Der Spiegel		0.00 sec
# W1 ste Stern		0.00 sec
# W1 sz Süddeutsche Zeitung		0.00 sec
# W1 tas SonntagsZeitung (Tages-Anzeiger)		0.00 sec
# W1 taz-pub die tageszeitung		0.00 sec
# W1 wwo Weltwoche		0.00 sec
# W1 zeit Die Zeit		0.00 sec
# W1 zta Tages-Anzeiger		0.00 sec
# W2 aan Aachener Nachrichten		0.00 sec
# W2 aaz Aachener Zeitung		0.00 sec
# W2 abo Aar-Bote		0.00 sec
# W2 alz Aller-Zeitung		0.00 sec
# W2 azm Abendzeitung		0.00 sec
# W2 baz Basler Zeitung		0.00 sec
# W2 bdz Badische Zeitung		0.00 sec
# W2 bez Berner Zeitung		0.00 sec
# W2 bku Berliner Kurier		0.00 sec
# W2 bli Blick		0.00 sec
# W2 boz Börsen-Zeitung		0.00 sec
# W2 bru Bayerische Rundschau		0.00 sec
# W2 bze B.Z.		0.00 sec
# W2 bun Der Bund		0.00 sec
# W2 bwa Braunauer Warte am Inn		0.00 sec
# W2 ctb Coburger Tageblatt		0.00 sec
# W2 dak Die Aktuelle		0.00 sec
# W2 daz Döbelner Allgemeine Zeitung		0.00 sec
# W2 dec Darmstädter Echo		0.00 sec
# W2 dki Die Kitzinger		0.00 sec
# W2 dnn Dresdner Neueste Nachrichten		0.00 sec
# W2 dol Dolomiten		0.00 sec
# W2 dpr Der Prignitzer		0.00 sec
# W2 eft Eichsfelder Tageblatt		0.00 sec
# W2 fnp Frankfurter Neue Presse		0.00 sec
# W2 frt Fränkischer Tag		0.00 sec
# W2 gaz General-Anzeiger Bonn		0.00 sec
# W2 gta Göttinger Tageblatt		0.00 sec
# W2 hab Handelsblatt		0.00 sec
# W2 hfz Hofheimer Zeitung		0.00 sec
# W2 hhz Hochheimer Zeitung		0.00 sec
# W2 hkr Höchster Kreisblatt		0.00 sec
# W2 hst Heilbronner Stimme		0.00 sec
# W2 htb Hohenloher Tagblatt		0.00 sec
# W2 hzz Hohenzollerische Zeitung		0.00 sec
# W2 kaz Kreis-Anzeiger		0.00 sec
# W2 klz Kleine Zeitung		0.00 sec
# W2 ksa Kölner-Stadtanzeiger		0.00 sec
# W2 kur Kurier (Österreich)		0.00 sec
# W2 lan Lauterbacher Anzeiger		0.00 sec
# W2 laz Lampertheimer Zeitung		0.00 sec
# W2 lru Lausitzer Rundschau		0.00 sec
# W2 msp Main-Spitze		0.00 sec
# W2 noz Neue Osnabrücker Zeitung		0.00 sec
# W2 nwt Neue Welt		0.00 sec
# W2 osz Ostsee-Zeitung		0.00 sec
# W2 paz Peiner Allgemeine Zeitung		0.00 sec
# W2 stb Straubinger Tagblatt		7.83 sec
# W2 tvd TV Digital		0.00 sec
# W2 vbw Volksblatt		36.78 sec
# W2 vzs Schweinfurter Volkszeitung		0.00 sec
# W2 w Die Welt		0.00 sec
# W2 was Welt am Sonntag		0.00 sec
# W3 beo Berner Oberländer		0.00 sec
# W3 bmo Bergische Morgenpost		0.00 sec
# W3 bue Bürstädter Zeitung		0.00 sec
# W3 bzg Bergedorfer Zeitung		0.00 sec
# W3 dgl Die Glocke		0.00 sec
# W3 hna Hessische Niedersächsische Allgemeine		0.00 sec
# W3 hat Haller Tagblatt		0.00 sec
# W3 jue Jüdische Allgemeine		0.00 sec
# W3 kir Kirner Zeitung		0.00 sec
# W3 kn Kieler Nachrichten		0.00 sec
# W3 kru Kölnische Rundschau		0.00 sec
# W3 kxp Kölner Express		0.00 sec
# W3 lhz Landhuter Zeitung		0.00 sec
# W3 ln Lübecker Nachrichten		0.00 sec
# W3 lvz Leipziger-Volkszeitung		0.00 sec
# W3 mag Märkische Allgemeine		0.00 sec
# W3 maz Allgemeine Zeitung		0.00 sec
# W3 mme Münchner Merkur		0.00 sec
# W3 mpo Main-Post		0.00 sec
# W3 muv Metzinger Uracher Volksblatt		0.00 sec
# W3 mze Mitteldeutsche Zeitung		0.00 sec
# W3 nbk Nordbayerischer Kurier		0.00 sec
# W3 ngz Neuss-Grevenbroicher Zeitung		0.00 sec
# W3 nkz Neue Kronen-Zeitung		0.00 sec
# W3 nlz Neue Luzerner Zeitung		0.00 sec
# W3 nnn Norddeutsche Neueste Nachrichten		0.00 sec
# W3 nnp Nassauische Neue Presse		0.00 sec
# W3 now Nordwest-Zeitung		0.00 sec
# W3 npr Neue Presse		0.00 sec
# W3 nvb Neues Volksblatt		0.00 sec
# W3 nvt Neue Vorarlberger Tageszeitung		0.00 sec
# W3 nwe Neue Westfälische		0.00 sec
# W3 nws Die Nordwestschweiz		0.00 sec
# W3 nwz Neue Württembergische Zeitung		0.00 sec
# W3 oaz Oschatzer Allgemeine Zeitung		0.00 sec
# W3 ohz Oberhessische Zeitung		0.00 sec
# W3 ovz Osterländer Volkszeitung		0.00 sec
# W3 pnn Potsdamer Neuste Nachrichten		0.00 sec
# W3 pnp Passauer Neue Presse		0.00 sec
# W3 rln Reutlinger Nachrichten		0.00 sec
# W3 rn Ruhr Nachrichten		0.00 sec
# W3 rpo Rheinische Post		0.00 sec
# W3 rsw Rundschau für den Schwäbischen Wald		0.00 sec
# W3 rue Rüsselsheimer Echo		0.00 sec
# W3 sbn Salzburger Nachrichten		0.00 sec
# W3 smp Solinger Morgenpost		0.00 sec
# W4 sta Der Standard		0.00 sec
# W4 tsp Der Tagesspiegel		0.00 sec
# W4 fpc Freie Presse		0.00 sec
# W4 giz Giessener Anzeiger		0.00 sec
# W4 haa Hamburger Abendblatt		0.00 sec
# W4 hdz Handelszeitung		0.00 sec
# W4 mib Mittelbayerische Zeitung		0.00 sec
# W4 oon Oberösterreichische Nachrichten		0.00 sec
# W4 otz Ostthüringer Zeitung		0.00 sec
# W4 rga Reutlinger General-Anzeiger		0.00 sec
# W4 rvz Rieder Volkszeitung		0.00 sec
# W4 saz Saale-Zeitung		0.00 sec
# W4 sbz Saarbrücker Zeitung		0.00 sec
# W4 sze Sächsische Zeitung		0.00 sec
# W4 scz Schwäbische Zeitung		0.00 sec
# W4 sct Schweinfurter Tagblatt		0.00 sec
# W4 svz Schweriner Volkszeitung		0.00 sec
# W4 sku Südkurier		0.00 sec
# W4 swp Südwest Presse		0.00 sec
# W4 tnz Taunus Zeitung		0.00 sec
# W4 tha Thüringer Allgemeine		0.00 sec
# W4 tlz Thüringische Landeszeitung		0.00 sec
# W4 ttz Tiroler Tageszeitung		0.00 sec
# W4 tvf Trierischer Volksfreund		0.00 sec
# W4 uan Usinger Anzeiger		0.00 sec
# W4 van Vorarlberger Nachrichten		0.00 sec
# W4 wez Westdeutsche Zeitung		0.00 sec
# W4 wfb Westfalen-Blatt		0.00 sec
# W4 wiz Wiener Zeitung		0.00 sec
# W4 wku Wiesbadener Kurier		0.00 sec
# W4 wor Wormser Zeitung		0.00 sec
#   0%|          | 0/157 [00:00<?, ?it/s]
# W1 bmp Berliner Morgenpost		0.00 sec
# W1 bzt-pub Berliner Zeitung		0.00 sec
# W1 dpr Die Presse		0.00 sec
# W1 flt Falter		0.00 sec
# W1 foc FOCUS		0.00 sec
# W1 haz Hannoversche Allgemeine		0.00 sec
# W1 hmp Hamburger Morgenpost		0.00 sec
# W1 mm Mannheimer Morgen		0.00 sec
# W1 news NEWS		0.00 sec
# W1 nku Nordkurier		0.00 sec
# W1 non Niederösterreichische Nachrichten		0.00 sec
# W1 nun Nürnberger Nachrichten		0.00 sec
# W1 nuz Nürnberger Zeitung		0.00 sec
# W1 nzs NZZ am Sonntag		0.00 sec
# W1 nzz Neue Zürcher Zeitung		0.00 sec
# W1 prf profil		0.00 sec
# W1 rhz Rhein-Zeitung		0.00 sec
# W1 sbl Sonntagsblick		0.00 sec
# W1 sgt St. Galler Tagblatt		0.00 sec
# W1 spiegel Der Spiegel		0.00 sec
# W1 ste Stern		0.00 sec
# W1 sz Süddeutsche Zeitung		0.00 sec
# W1 tas SonntagsZeitung (Tages-Anzeiger)		0.00 sec
# W1 taz-pub die tageszeitung		0.00 sec
# W1 wwo Weltwoche		0.00 sec
# W1 zeit Die Zeit		0.00 sec
# W1 zta Tages-Anzeiger		0.00 sec
# W2 aan Aachener Nachrichten		0.00 sec
# W2 aaz Aachener Zeitung		0.00 sec
# W2 abo Aar-Bote		0.00 sec
# W2 alz Aller-Zeitung		0.00 sec
# W2 azm Abendzeitung		0.00 sec
# W2 baz Basler Zeitung		0.00 sec
# W2 bdz Badische Zeitung		0.00 sec
# W2 bez Berner Zeitung		0.00 sec
# W2 bku Berliner Kurier		0.00 sec
# W2 bli Blick		0.00 sec
# W2 boz Börsen-Zeitung		0.00 sec
# W2 bru Bayerische Rundschau		0.00 sec
# W2 bze B.Z.		0.00 sec
# W2 bun Der Bund		0.00 sec
# W2 bwa Braunauer Warte am Inn		0.00 sec
# W2 ctb Coburger Tageblatt		0.00 sec
# W2 dak Die Aktuelle		0.00 sec
# W2 daz Döbelner Allgemeine Zeitung		0.00 sec
# W2 dec Darmstädter Echo		0.00 sec
# W2 dki Die Kitzinger		0.00 sec
# W2 dnn Dresdner Neueste Nachrichten		0.00 sec
# W2 dol Dolomiten		0.00 sec
# W2 dpr Der Prignitzer		0.00 sec
# W2 eft Eichsfelder Tageblatt		0.00 sec
# W2 fnp Frankfurter Neue Presse		0.00 sec
# W2 frt Fränkischer Tag		0.00 sec
# W2 gaz General-Anzeiger Bonn		0.00 sec
# W2 gta Göttinger Tageblatt		0.00 sec
# W2 hab Handelsblatt		0.00 sec
# W2 hfz Hofheimer Zeitung		0.00 sec
# W2 hhz Hochheimer Zeitung		0.00 sec
# W2 hkr Höchster Kreisblatt		0.00 sec
# W2 hst Heilbronner Stimme		0.00 sec
# W2 htb Hohenloher Tagblatt		0.00 sec
# W2 hzz Hohenzollerische Zeitung		0.00 sec
# W2 kaz Kreis-Anzeiger		0.00 sec
# W2 klz Kleine Zeitung		0.00 sec
# W2 ksa Kölner-Stadtanzeiger		0.00 sec
# W2 kur Kurier (Österreich)		0.00 sec
# W2 lan Lauterbacher Anzeiger		0.00 sec
# W2 laz Lampertheimer Zeitung		0.00 sec
# W2 lru Lausitzer Rundschau		0.00 sec
# W2 msp Main-Spitze		0.00 sec
# W2 noz Neue Osnabrücker Zeitung		0.00 sec
# W2 nwt Neue Welt		0.00 sec
# W2 osz Ostsee-Zeitung		0.00 sec
# W2 paz Peiner Allgemeine Zeitung		0.00 sec
# W2 stb Straubinger Tagblatt		11.26 sec
# W2 tvd TV Digital		0.00 sec
# W2 vbw Volksblatt		0.00 sec
# W2 vzs Schweinfurter Volkszeitung		0.00 sec
# W2 w Die Welt		0.00 sec
# W2 was Welt am Sonntag		0.00 sec
# W3 beo Berner Oberländer		0.00 sec
# W3 bmo Bergische Morgenpost		0.00 sec
# W3 bue Bürstädter Zeitung		0.00 sec
# W3 bzg Bergedorfer Zeitung		0.00 sec
# W3 dgl Die Glocke		0.00 sec
# W3 hna Hessische Niedersächsische Allgemeine		0.00 sec
# W3 hat Haller Tagblatt		0.00 sec
# W3 jue Jüdische Allgemeine		0.00 sec
# W3 kir Kirner Zeitung		0.00 sec
# W3 kn Kieler Nachrichten		0.00 sec
# W3 kru Kölnische Rundschau		0.00 sec
# W3 kxp Kölner Express		0.00 sec
# W3 lhz Landhuter Zeitung		0.00 sec
# W3 ln Lübecker Nachrichten		0.00 sec
# W3 lvz Leipziger-Volkszeitung		0.00 sec
# W3 mag Märkische Allgemeine		0.00 sec
# W3 maz Allgemeine Zeitung		0.00 sec
# W3 mme Münchner Merkur		0.00 sec
# W3 mpo Main-Post		0.00 sec
# W3 muv Metzinger Uracher Volksblatt		0.00 sec
# W3 mze Mitteldeutsche Zeitung		0.00 sec
# W3 nbk Nordbayerischer Kurier		0.00 sec
# W3 ngz Neuss-Grevenbroicher Zeitung		0.00 sec
# W3 nkz Neue Kronen-Zeitung		0.00 sec
# W3 nlz Neue Luzerner Zeitung		0.00 sec
# W3 nnn Norddeutsche Neueste Nachrichten		0.00 sec
# W3 nnp Nassauische Neue Presse		0.00 sec
# W3 now Nordwest-Zeitung		0.00 sec
# W3 npr Neue Presse		0.00 sec
# W3 nvb Neues Volksblatt		0.00 sec
# W3 nvt Neue Vorarlberger Tageszeitung		0.00 sec
# W3 nwe Neue Westfälische		0.00 sec
# W3 nws Die Nordwestschweiz		0.00 sec
# W3 nwz Neue Württembergische Zeitung		0.00 sec
# W3 oaz Oschatzer Allgemeine Zeitung		0.00 sec
# W3 ohz Oberhessische Zeitung		0.00 sec
# W3 ovz Osterländer Volkszeitung		0.00 sec
# W3 pnn Potsdamer Neuste Nachrichten		0.00 sec
# W3 pnp Passauer Neue Presse		142.08 sec
# W3 rln Reutlinger Nachrichten		58.43 sec
# W3 rn Ruhr Nachrichten		0.00 sec
# W3 rpo Rheinische Post		249.50 sec
# W3 rsw Rundschau für den Schwäbischen Wald		0.00 sec
# W3 rue Rüsselsheimer Echo		0.00 sec
# W3 sbn Salzburger Nachrichten		0.00 sec
# W3 smp Solinger Morgenpost		0.00 sec
# W4 sta Der Standard		0.00 sec
# W4 tsp Der Tagesspiegel		0.00 sec
# W4 fpc Freie Presse		0.00 sec
# W4 giz Giessener Anzeiger		0.00 sec
# W4 haa Hamburger Abendblatt		0.00 sec
# W4 hdz Handelszeitung		0.00 sec
# W4 mib Mittelbayerische Zeitung		0.00 sec
# W4 oon Oberösterreichische Nachrichten		0.00 sec
# W4 otz Ostthüringer Zeitung		0.00 sec
# W4 rga Reutlinger General-Anzeiger		0.00 sec
# W4 rvz Rieder Volkszeitung		0.00 sec
# W4 saz Saale-Zeitung		0.00 sec
# W4 sbz Saarbrücker Zeitung		0.00 sec
# W4 sze Sächsische Zeitung		0.00 sec
# W4 scz Schwäbische Zeitung		0.00 sec
# W4 sct Schweinfurter Tagblatt		0.00 sec
# W4 svz Schweriner Volkszeitung		0.00 sec
# W4 sku Südkurier		0.00 sec
# W4 swp Südwest Presse		0.00 sec
# W4 tnz Taunus Zeitung		0.00 sec
# W4 tha Thüringer Allgemeine		0.00 sec
# W4 tlz Thüringische Landeszeitung		0.00 sec
# W4 ttz Tiroler Tageszeitung		0.00 sec
# W4 tvf Trierischer Volksfreund		0.00 sec
# W4 uan Usinger Anzeiger		0.00 sec
# W4 van Vorarlberger Nachrichten		0.00 sec
# W4 wez Westdeutsche Zeitung		0.00 sec
# W4 wfb Westfalen-Blatt		0.00 sec
# W4 wiz Wiener Zeitung		0.00 sec
# W4 wku Wiesbadener Kurier		0.00 sec
# W4 wor Wormser Zeitung		0.00 sec

# %%
try:
    raise Exception("hello")
except Exception as e:
    print(str(e))

# %%
# from src.data.news.dereko.scraping import parse_html_table

# df = parse_html_table(html)
# print(len(df))
# df.sample(20)

# %%
from pprint import pprint

from src.data.protests.keywords import climate_queries

print(climate_queries(mode="dereko", short=True)["protest"])
# Out:
# (klimawandel OR erderwärmung OR klimaschutz OR klimagerechtigkeit OR klimapolitik OR klimaneutral* OR (hambacher forst) OR lützerath) AND (*protest* OR *demo OR *demonstr* OR *kundgebung OR *versamm* OR *besetz* OR *streik* OR *blockade OR *blockier* OR sitzblock* OR *aktivis* OR *marsch OR klimabewegung OR klimaaktivis* OR klimastreik* OR (for future) OR (4 future) OR (extinction rebellion) OR (just stop oil) OR (letzte* generation) OR klimakleb* OR (ende gelände) OR (end fossil) OR (fossil occupy) OR greenpeace)

# %%
(klimawandel OR erderwärmung OR klimaschutz OR klimagerechtigkeit OR klimapolitik OR klimaneutral* OR (hambacher forst) OR lützerath) AND (*protest* OR *demo OR *demonstr* OR *kundgebung OR *versamm* OR *besetz* OR *streik* OR *blockade OR *blockier* OR sitzblock* OR *aktivis* OR *marsch OR klimabewegung OR klimaaktivis* OR klimastreik* OR (for future) OR (4 future) OR (extinction rebellion) OR (just stop oil) OR (letzte* generation) OR klimakleb* OR (ende gelände) OR (end fossil) OR (fossil occupy) OR greenpeace)
