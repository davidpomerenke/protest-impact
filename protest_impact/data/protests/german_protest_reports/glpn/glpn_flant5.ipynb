# %% [markdown]
# # Protest event detection with FLAN-T5
#
# FLAN-T5 is a recent Google model that is finetuned on a variety of tasks, comparable to InstructGPT (which makes GPT3 so nice). It is train on multiple languages, including German. I hope that it may outperform the German Electra model, with or even without task-specific finetuning.
#
# Since this is a sequence-to-sequence model, I have to change the setup slightly, but basically this is a copy of [`01-27.ipynb`](01-27.ipynb).
#
# This notebook is to be run on Google Colab with GPU support. Some of the original outputs are missing, but I copied the results as text.

# %%
# !pip install transformers datasets evaluate

# %%
from datasets import load_dataset

dataset = load_dataset(
    "csv",
    data_files={
        "train": "drive/MyDrive/0 Protest Impact/Protest Event Replication/data/glpn_train.csv",
        "dev": "drive/MyDrive/0 Protest Impact/Protest Event Replication/data/glpn_dev.csv",
        "test": "drive/MyDrive/0 Protest Impact/Protest Event Replication/data/glpn_test.csv",
        "test.time": "drive/MyDrive/0 Protest Impact/Protest Event Replication/data/glpn_test-time.csv",
        "test.loc": "drive/MyDrive/0 Protest Impact/Protest Event Replication/data/glpn_test-loc.csv",
    },
)
dataset

# %%
dataset["train"]["labels"][:10]
# Out:
# ['relevant',
#  'relevant',
#  'irrelevant',
#  'irrelevant',
#  'irrelevant',
#  'relevant',
#  'irrelevant',
#  'relevant',
#  'irrelevant',
#  'relevant']

# %%
dataset = dataset.map(
    lambda x: {"response": "Ja" if x["labels"] == "relevant" else "Nein"}
)

# %%
dataset["train"]["response"][:10]
# Out:
# ['Ja', 'Ja', 'Nein', 'Nein', 'Nein', 'Ja', 'Nein', 'Ja', 'Nein', 'Ja']

# %%
from datasets import ClassLabel

dataset = dataset.cast_column("labels", ClassLabel(names=["irrelevant", "relevant"]))
dataset = dataset.rename_column("labels", "label")
dataset["train"]["label"][:10]
# Out:
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d6a0385c29754dbe/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-e3922e0d52ff2ea2.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d6a0385c29754dbe/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-3635d06665d4addd.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d6a0385c29754dbe/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-9283e936e27c3564.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d6a0385c29754dbe/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-349c3e9a523e9524.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d6a0385c29754dbe/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-173d5d9b3ba8bd39.arrow
# [1, 1, 0, 0, 0, 1, 0, 1, 0, 1]

# %%
prompt = """

Zu Protesteregnissen zählen vielfältige Protestformen, wie Demonstrationen, Streiks, Blockaden, Unterschriftensammlungen, Besetzungen, Boykotte, etc. Beschreibt dieser Zeitungsartikel ein Protestereignis? Antworte mit "Ja" oder "Nein".

Antwort: """
dataset = dataset.map(lambda x: {"prompt": x["excerpt"] + prompt})
print(dataset["train"]["prompt"][84])
# Out:
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d6a0385c29754dbe/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-6ef05c49673f874f.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d6a0385c29754dbe/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-a2070d9ecdc9a1cf.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d6a0385c29754dbe/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-fa58dc9956ddf8f1.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d6a0385c29754dbe/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-b0976a8e23e85c26.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d6a0385c29754dbe/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-e33439a9c237b4a1.arrow
# Stuttgarter Zeitung 2010-06-19 100 000 Unterschriften gegen tödliche Waffen Von Kathrin Wesely  Gemeinsam mit der Initiative "Keine Mordwaffen als Sportwaffen!" ist das Aktionsbündnis Amoklauf Winnenden (Rems-Murr-Kreis) gestern bei Katrin Göring-Eckardt in Berlin vorstellig geworden. Die Delegation hat der grünen Bundestagsvizepräsidentin mehr als 100 000 Unterschriften gegen tödliche Sportwaffen überreicht. In seinem Appell an den Bundestag fordert das Aktionsbündnis das Verbot großkalibriger Handfeuerwaffen in Privathaushalten und die getrennte Aufbewahrung von Waffen und Munition. Außerdem hat das Aktionsbündnis der Vizepräsidentin 85 000 Unterschriften für ein Verbot von Killerspielen übergeben. Vertreter aller Bundestagsfraktionen begrüßten bei der Übergabe der Unterschriften auf den Stufen des Reichstags das Engagement der betroffenen Eltern aus Winnenden. "In der anschließenden Bundestagsdebatte waren die politischen Lager aber wieder gespalten", bedauert Carlos Bolesch, einer der Sprecher des Aktionsbündnisses. Der Grünen-Innenexperte Wolfgang Wieland forderte, langfristig alle Waffen aus Privathaushalten zu verbannen und als Sofortmaßnahme die getrennte Aufbewahrung von Munition und Waffen durchzusetzen: "Wenn beides nicht im Haushalt ist, kann der Täter damit nicht losstürmen." Zudem forderte der grüne Politiker ein Verbot großkalibriger Kurzwaffen und halbautomatischer Waffen für den Schießsport. Der CDU-Abgeordnete Günter Lach hingegen kritisierte, die Forderungen der Grünen gingen zu weit. Sie stellten Schützen und Jäger unter einen Generalverdacht. Auch die SPD-Abgeordnete Gabriele Fograscher sprach sich gegen die Vorschläge der Grünen aus. Der FDP-Politiker Serkan Tören sagte, Deutschland habe schon eines der schärfsten Waffengesetze. Der Linken-Politiker Frank Tempel erklärte hingegen, die Forderungen der Grünen gingen in die richtige Richtung. Hardy Schober, der Vorsitzende des Aktionsbündnisses, zeigte sich über die ablehnenden Stimmen aus der Politik zur Verschärfung des Waffenrechts empört: "Alle sehen die latente Gefahr von Amokläufen. Wie wollen sich unsere Politiker rechtfertigen, wenn wieder etwas passiert?" Der Druck der Waffenlobby könne längst nicht mehr als ausreichende Erklärung für die Untätigkeit der Politik herhalten, so Hardy Schober, "da eine breite Basis in der Bevölkerung unsere Forderung unterstützt". Das belege die erfolgreiche Unterschriftenaktion des Aktionsbündnisses, bei der "Privatpersonen Tausende Menschen dazu bewegen konnten, mit ihrem Namen für mehr Sicherheit in unserer Gesellschaft einzutreten". Die Initiative "Keine Mordwaffen als Sportwaffen!" will langfristig durchsetzen, dass alle tödlichen Waffen im Schießsport untersagt werden. Dazu will sie bis Ende Juli fristgemäß gegen das neue Waffengesetz Verfassungsbeschwerde einlegen. "Wie wollen sich Politiker rechtfertigen, wenn wieder etwas passiert?" Hardy Schober, Vorstand des Aktionsbündnisses
#
# Zu Protesteregnissen zählen vielfältige Protestformen, wie Demonstrationen, Streiks, Blockaden, Unterschriftensammlungen, Besetzungen, Boykotte, etc. Beschreibt dieser Zeitungsartikel ein Protestereignis? Antworte mit "Ja" oder "Nein".
#
# Antwort:

# %%
from transformers import AutoTokenizer, T5ForConditionalGeneration

# model_name = "google/flan-t5-base"
model_name = "google/flan-t5-large"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = T5ForConditionalGeneration.from_pretrained(model_name)

model_name = model_name.split("/")[1]

# %%
def tokenize_function(examples):
    return tokenizer(
        examples["prompt"],
        text_target=examples["response"],
        padding="max_length",
        truncation=True,
        max_length=512,
        return_tensors="pt",
    )


tokenized_dataset = dataset.map(tokenize_function, batched=True)
tokenized_dataset

# %%
import evaluate
import numpy as np

metric = evaluate.load("bleu")


def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %%
import torch

responses = {}
for split in ["test", "test.time", "test.loc"]:
    print(split)
    responses[split] = []
    input_ids = tokenizer(
        dataset[split]["prompt"],
        padding="max_length",
        truncation=True,
        max_length=512,
        return_tensors="pt",
    )  # .to("cuda")
    output = model.generate(**input_ids)
    responses_ = tokenizer.batch_decode(output, skip_special_tokens=True)
    for response in responses_:
        if "ja" in response.lower():
            label = 1
        elif "nein" in response.lower():
            label = 0
        else:
            print(response)
            label = 0
            # label = None
        responses[split].append(label)
# Out:
# test
# /usr/local/lib/python3.8/dist-packages/transformers/generation/utils.py:1273: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# erschwert, dass die Fraktion der islamkritischen Legida-Fraktion
# Leipzig steht erneut vor einem Ausnahmezustand: Nachdem das islamkritische Bündnis
# che
# Konferenz erteilt.
# Legida-Fraktion für eine Bürgerbegehren tragen.
# ffentlichkeitsmitglied, der ffentlichkeitsmitglied hat seinen ffentlichkeit
# hnliches hnliches hnliches hnliche
# Die Bürger von Untertürkheim empfanden den Burschenschaftstag und die prot
# Im Prozess wegen der Ermordung einer Eislinger Familie haben sich die Anwält
# Ein Ehepaar aus einer kleinen Gemeinde im Landkreis Böblingen muss seine drei Kinder zur
# Der Anlass für die blautige Schlägerei, bei der am 1. August 2008
# Die ffentlichkeit hat sich während der ffentlichkeitsauftritte in Ge
# hnliches hnliches hnliches
# Dietlichkeitsgrund, sondern auf der politischen Grundlage.
# nderungsantrag nderungsantrag nderungsantrag
# Kinderstätten zu reservieren, um die Kinder zu erlernen.
# Der Widerstand gegen die milliardenteure Tieferlegung des Bahnhofs, gegen die
# Der sanierte Landesstraße zwischen Schorndorf und dem Teilort Schlichten
# Das Organisationstalent der Eltern ist wieder gefordert. Wer nicht über die Pfings
# Stuttgart 21-Gegner ist es nicht nur klar, wie die Aktionen
# Flüchtlinge, sondern auch die Menschen, die sich heute ausfließen, ist ein
# Die Fraktion der IG Metall hat es geschafft, die Fraktion
# Die Europäische Union" ist es, ist es es,
# Der Protestzug, der in weitem Bogen vom Hauptbahnhof über Uni,
# Teilerfolg für die eigens eingerichtete neuköpfige Ermittlungs
# 2010-03-22 Alte Lieder und neue Sorgen Von Thomas Borgmann Eine
# Rund 250 Anlieger und Zuffenhausener Bürger haben gestern für etwa eine dreiviertel
# Ulmer Staatsanwaltschaft hat diesen Woche eine Reihe von Fällen, die
# Stuttgarter Kriminalpolizei die gesamten zwölf-köpfigen Gruppe sicher
# In ihrem Vorwärtsdrang hat die Gewerkschaft der Flugsicherung (Gd
# Kurz nach 2 Uhr nachts begann es in der ganzen Region, in
# Die Bürgerinitiative Lärm Denkendorf ist bereits ein eingetragener Verein mit rund 300
# Der Streik, wenn die Gewerkschaftmitglieder mit der nötigen Dreivier
# - der Bahnhof - ist es, daß wir nicht entziehen
# Das Bündnis 'Kreis Göppingen nazifrei' will mit
# :
# 2010-07-13 Stadt hat das Skinhead-Konzert zu Recht aufgelöst
# Der 6. Senat verurteilte gestern einen 36-Jährigen, der zuletzt in
# lyn Mehr unter www.lvz-online.de
# Gewitterfront zu einem großen Unfall.
# Während der Versammlung ergriffene sich die Sicherheitskräfte in der Halle.
# DFS-Konzern - der IG Metall - - - -
# Der Anlass für den blutigen Streit, bei dem am 1. August nahe
# 2010-08-02 Besonnen bleiben - Kommentar
# Der Machtkampf zwischen VW und Porsche droht vollends aus dem Ruder zu
# Am Tag der offenen Tür in der Villa Reitzenstein Fraktionswagen in den Seiten
# Die Lufthansa-Gewerkschaft Ufo hat bereits am Dienstag mehr
# nderungsantrag - nderungsantrag - ist ein
# Stuttgart und in den Landkreisen Rems-Murr, Böblingen und Ludwigsburg
# , Aktionen, Aktionen, Aktionen, Aktionen,
# Mit Tausenden von losgelassenen grünen Luftballons, einer als "U
# Der Konflikt zweier Völker ist am Sonntag - einmal mehr - in der Stuttgart
# Ralf Michelfelder von der Waiblinger Polizei.
# Winfried Kretschmann hat schon immer mit seiner Partei gegen die Tieferlegung des Stuttgart
# Die aktive Rolle des SS-Stadtrates Hannes Rock
# öffentlichen Platz zu treten
# Delitzsch Kliniken zu erfordern, ist das nicht recht, denn e
# Die Stimmung ist aufgeheizt auf dem Theaterplatz direkt an der Semperoper. Über
# Antworten zu dieser Frage
# Konferenzen, Konferenzen, Konferenzen, Konferenzen, Konferenzen
# Streiks - die letzten waren - - - -
# Stocker hat es geschafft, sich zu erbrechen.
# Verdi, er hätte gesagt, dass er die ffentlichkeit -
# Die öffentlichen Verkehrsmittel sind weiterhin verantwortlich für die öffentlichen Verkehrsmittel.
# nderungsantrag nderungsantrag nderungsantrag
# Die Aktion auf der A 81 verboten
# , Konferenz, Konferenz, Konferenz, Konferenz, Konferenz, Konferenz
# Besichtigen die Flüchtlingsfrauen in Bremen.
# Protests and demonstrations overschatten the celebration Turbulent and na
# Dresden, die letzten Tage der letzten Kriege, die letzten Tage der letzten
# LEIPZV0020150713eb7d0002m Leipziger Volkszeit
# Der Widerstand gegen Stuttgart 21 geht auch nach der friedlichen Großdemonstration am
# Kinderbetreuung, die sie erfreut haben.
# BHV Bremische Hafenvertretung, dass es sich weiterhin auf
# Der man hat sich ernsthaft erfreut,
# Während dieser Reden stand einer wie versteinert auf der Bühne, wohl wissen
# Während eine Teil der Demonstranten vor dem Nordflügel protestierten, block
# Legida"-Kundgebungsveranstaltung" oder es wird e
# Die Bürgerinitiative "Fellbach ist nicht Manhattan" ist zu spät gekommen. Aus formal
# Die rangeleien im Rathaus zwischen Demonstranten und Stadträten vor der
# Die Proteste gegen den bevorstehenden Abriss des nördlichen Seiten
# Bürgerinitiative will die ehemalige Papierfabrik in Golzern retten; App
# Der 25-jährige Türkei, der allein in einer Wohnung im Stuttgarter Osten
# nderungsantrage die ffentlichkeit entziehen.
# Protesteregnissen zählen vielfältige Protestformen, wie Demon
# Islamische Dschihad-Union' hat seinen Leben wieder in der Lage.
# - 33?
# Germanys störte es, dass es sich beim
# Der juristische Streit um die knapp sieben Kilometer lange Nordumfahrung, deren
# Die Lokführer haben gestern Morgen wieder weite Teile des Schienenverkehrs lah
# Mehr als 250 Menschen protestieren vor dem Stuttgarter Rathaus gegen die Gewalt im Iran von Christine
# Die Fraktion der Europäischen Volkspartei (EGP) hat sich längst nicht
# AICHELBERG (com). Der neue und alte Bürgermeister in Aichelberg im
# teilnimmt die Staats- und Finanzminister (ddb) auch bei den Protest
# Wegen Handels mit illegalen Drogen hat das Landgericht Stuttgart gestern einen 36-Jährige
# Yes
# Bundesstraße 27.
# strafbarte.
# Mainn
# Das ist das erste Mal, dass ich aktiv demonstriere.
# Lufthansa-Piloten legen von Montag an den Flugverkehr lah
# Nach den heftigen Gewittern in der Nacht zum Sonntag hat die Stuttgarter Polizei
# Die Baumverpflanzungen vor dem Nordausgang des Stuttgarter Hauptbahnhof sind gestern
# yes
# In schlechtem Deutsch hat der Internetblogger neben einem Amoklauf an der
# LEIPZV0020151202eb9s00147 Leipziger Volkszeitung
# hnliche Protesteregnissen sind Demonstrationen,
# Der VGH zeigt die Grenzen der Versammlungsfreiheit auf
# 2010-08-24 Palmer wirft Schuster "Machtmissbrauch" vor
# Im Schlossgarten wächst der Widerstand Sie sind drei von inzwischen fast elftausend. Ur
# Oerlikon Schlafhorst, die es in Ebersbach
# LEIPZV0020150612eb6c0000v
# Demonstrationsrechte - wie das Recht der Demonstration -
# 2010-04-29 Grundlage fordert mehr Protest Von Harald Beck Wir gehen vor!
# Der Polizei hat sich deshalb ernsthaft erwiesen, dass
# Die ländlichen Kinobetreiber, die einen Film nicht ersetzen,
# Die Demonstrationen erschweren sich deshalb, weil sie sich
# - es gibt es unterschiedliche Formen von Protestereg
# Protests, Protests, Protests, Protests, Protests
# In einem Zeltcamp oberhalb des Stuttgarter Stadtbezirks Mühlhausen
# ", die es ergibt, dass die Demonstrationen unter
# Die Zeit der großen Hochschulproteste scheint an diesem kühlen Tag im März
# Der angeklagte Gymnasiast - der angeklagte 18
# Die Firma Porsche hatte einige Mühe für die Aufklärung des Sachverhalts aufgewende
# Die Aktivitäten der Project-X-Partymacher auf der Internetplattform Facebook tendierten zumindest
# Mit Trommeln und Trillerpfeifen sind gestern rund 12 000 Be
# LEIPZV0020150908eb980002o Die fremdenf
# Von Viola Volland Es ist eine Entscheidung mit Signalwirkung, die gestern bekannt gegeben wurde
# Der Bürgerinitiative hat sich in der Text zum Bürgerentscheid nicht gerechtfertigt,
# Graffiti-Sprüher haben in Kirchheim Fassaden verunstal
# Die Demonstration - die Demonstration - die Demon
# Fritz Mielert ließ seinen Verteidiger sprechen: "Warum war das
# Der Protester hat sich schließlich in der letzten Woche ernst
# StZ_20090523_DSIBD_1206
# StZ_20091110_KSNM_717 Stuttgarter Zeitung 2009-11-10 Ke
# StZ_20090122_SMEIH_276 Stuttgarter Zeitung 2009-01
# StZ_20090618_PWVM_540 Stuttgarter Zeitung 2009-06
# StZ_20090904_RSÜSH_370 Stuttgarter Zeitung 2009-09-04
# StZ_20090724_IFBG_657 Stuttgarter Zeitung 2009-07-24
# Daimler-Konzern kann mit dem Beschluss des Oberlandesgerichts (OLG
# Während der Revierreform hat sich die Polizei in der Stadt erschwert
# "
# StZ_20090811_IDSTI_519 Stuttgarter Zeitung 2009-08-11
# StZ_20090310_KVGCM_424 Stuttgarter Zeitung 2009-03
# StZ_20090312_DFIK_552 Stuttgarter Zeitung 2009-
# StZ_20090824_DIWAW_378 Stuttgarter Zeitung 2009-
# StZ_20090421_PBKSU_438 Stuttgarter Zeitung 2009-04-21
# StZ_20090430_IDPWU_436 Stuttgarter Zeitung 2009-04
# Es ist noch nicht allzu oft vorgekommen, dass Ministerpräsident Günther
# Esslingen, Göppingen, Kirchheim und Nürtingen - die
# StZ_20090121_DRDRK_681 Stuttgarter Zeitung 2009-01-21
# Stricker Aufzüge.
# Oft freiwillig, sehr häufig aber auch ohne es zu wissen, geben Menschen persönliche
# StZ_20090430_DNLDR_546 Der Lieblingsort des Ober
# StZ_20090427_HDWUR_280 Stuttgarter Zeitung 2009-04-27
# Sana-Herzchirurgie ist rechtmäßig, er versichert, dass die Stadt
# StZ_20090625_EPSFG_437 Stuttgarter Zeitung 2009-06-25
# StZ_20090429_DSßPW_478 Stuttgarter Zeitung 2009-04
# Peter Huber hat diesen Tag in der Offensive gegangen.
# StZ_20090110_BFWKL_292
# StZ_20090925_KWOM_257 Stuttgarter Zeitung 2009-09-25
# Bürgernahes Landkreisplattform.
# StZ_20090320_EFDM_654 Stuttgarter Zeitung 2009-03
# StZ_20090103_BÜBDG_347 Stuttgarter Zeitung 2009-01
# StZ_20090107_TFTDW_368 Stuttgarter Zeitung 2009-01-
# StZ_20090617_GßFEU_1202
# Gingen hat das Recht, die B-10-Umgehungsstraße weiter
# StZ_20090722_SDK_666
# Oft lösen die Sozialrichter ihrer Fälle ohne Urteil - KLAGEWELLE
# StZ_20091221_DUE_739 Stuttgarter Zeitung 2009-12-21 Das
# islamischen
# StZ_20090425_BKF_607 Stuttgarter Zeitung 2009
# StZ_20090824_GR_646 Stuttgarter Zeitung 2009-08-24 Global
# test.time

# %% [markdown]
# In many cases it does not answer with Yes or No but with some nonsense :/
#
# In part this may be because the prompt is truncated when the article is very long.

# %%
responses["test"][:10]

# %%
eval_results = {}
for split in ["test", "test.time", "test.loc"]:
    eval_results[split] = metric.compute(
        predictions=responses[split], references=list(dataset[split]["label"])
    )
eval_results

# %% [markdown]
# **flan-t5-base:**
# {'test': {'f1': 0.6657183499288764},
#  'test.time': {'f1': 0.6810035842293908},
#  'test.loc': {'f1': 0.26666666666666666}}

# %%
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir=f"drive/MyDrive/0 Protest Impact/Protest Event Replication/model/{model_name}/checkpoints",
    evaluation_strategy="epoch",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    lr_scheduler_type="linear",
    warmup_ratio=0.1,
    learning_rate=5e-6,
    weight_decay=0.2,
    num_train_epochs=6,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["dev"],
    compute_metrics=compute_metrics,
)

# %%
from pathlib import Path

from transformers import T5ForConditionalGeneration

if Path(model_location).exists():
    model = T5ForConditionalGeneration.from_pretrained(model_location)
else:
    trainer.train()
    trainer.save_model(model_location)
# Out:
# loading configuration file drive/MyDrive/0 Protest Impact/Protest Event Replication/model/flan-t5-base/checkpoints/checkpoint-2000/config.json
# Model config T5Config {
#   "_name_or_path": "google/flan-t5-base",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.26.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading weights file drive/MyDrive/0 Protest Impact/Protest Event Replication/model/flan-t5-base/checkpoints/checkpoint-2000/pytorch_model.bin
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.0"
# }
#
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at drive/MyDrive/0 Protest Impact/Protest Event Replication/model/flan-t5-base/checkpoints/checkpoint-2000/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# loading configuration file drive/MyDrive/0 Protest Impact/Protest Event Replication/model/flan-t5-base/checkpoints/checkpoint-2000/generation_config.json
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.0"
# }

# %%
from collections import Counter

Counter(dataset["test"]["label"])
# Out:
# Counter({1: 330, 0: 217})

# %%
import torch

responses = {}
for split in ["test", "test.time", "test.loc"]:
    print(split)
    responses[split] = []
    input_ids = tokenizer(
        dataset[split]["prompt"],
        padding="max_length",
        truncation=True,
        max_length=512,
        return_tensors="pt",
    )  # .to("cuda")
    output = model.generate(**input_ids)
    responses_ = tokenizer.batch_decode(output, skip_special_tokens=True)
    for response in responses_:
        if "ja" in response.lower():
            label = 1
        elif "nein" in response.lower():
            label = 0
        else:
            print(response)
            label = 0
            # label = None
        responses[split].append(label)
# Out:
# test
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.0"
# }
#
# /usr/local/lib/python3.8/dist-packages/transformers/generation/utils.py:1273: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.0"
# }
# test.time
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.0"
# }
# Mit dem Namen des islamischen Botschaften in Leipzig.
# test.loc

# %%
eval_results = {}
for split in ["test", "test.time", "test.loc"]:
    eval_results[split] = metric.compute(
        predictions=responses[split], references=list(dataset[split]["label"])
    )
eval_results
# Out:
# {'test': {'f1': 0.7525655644241733},
#  'test.time': {'f1': 0.8304821150855365},
#  'test.loc': {'f1': 0.31010452961672474}}

# %% [markdown]
# Above are the main results. They are worse than the G-Electra model, especially for test.loc, maybe due to prompt truncation.

# %% [markdown]
# Evaluation of **flan-t5-base** during training (this is faked from restored checkpoint, as I am too lazy to convert the F1 metric to work with the Huggingface Seq2Seq Trainer):
#
# - after 500 batches:
#   - 'test': {'f1': 0.0},
#   - 'test.time': {'f1': 0.00373},
#   - 'test.loc': {'f1': 0.0}
# - after 2000 batches:
#   - 'test': {'f1': 0.752},
#   - 'test.time': {'f1': 0.830},
#   - 'test.loc': {'f1': 0.310}
# - after 2500 batches:
#   - 'test': {'f1': 0.752},
#   - 'test.time': {'f1': 0.829},
#   - 'test.loc': {'f1': 0.304}
# - after complete training:
#   - 'test': {'f1': 0.752},
#   - 'test.time': {'f1': 0.829},
#   - 'test.loc': {'f1': 0.304}
