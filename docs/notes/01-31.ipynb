# %% [markdown]
# # Simple approaches to event detection

# %%
from protest_impact.data.protests.detection import load_glpn_dataset

glpn = load_glpn_dataset()
# Out:
# Using custom data configuration default-552cac500ccb144a
# Found cached dataset csv (/Users/david/.cache/huggingface/datasets/csv/default-552cac500ccb144a/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
#   0%|          | 0/5 [00:00<?, ?it/s]
# Loading cached processed dataset at /Users/david/.cache/huggingface/datasets/csv/default-552cac500ccb144a/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-ceafcab5597f7c17.arrow
# Loading cached processed dataset at /Users/david/.cache/huggingface/datasets/csv/default-552cac500ccb144a/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-41bc297fe33d9da3.arrow
# Loading cached processed dataset at /Users/david/.cache/huggingface/datasets/csv/default-552cac500ccb144a/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-201012f13e291afc.arrow
# Loading cached processed dataset at /Users/david/.cache/huggingface/datasets/csv/default-552cac500ccb144a/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-b939ffa2b84d33a0.arrow
# Loading cached processed dataset at /Users/david/.cache/huggingface/datasets/csv/default-552cac500ccb144a/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-7a73a9f0937f0e26.arrow

# %%
# create tfidf features
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    max_df=0.95,
    min_df=2,
    max_features=1000,
    ngram_range=(1, 3),
)

tfidf.fit(glpn["train"]["excerpt"])
# Out:
# TfidfVectorizer(max_df=0.95, max_features=1000, min_df=2, ngram_range=(1, 3))

# %%
from sklearn.linear_model import LogisticRegression

# make a pipeline
from sklearn.pipeline import Pipeline

pipe = Pipeline(
    [
        ("tfidf", TfidfVectorizer()),
        ("clf", LogisticRegression()),
    ]
)

# make a grid search
from sklearn.model_selection import GridSearchCV

param_grid = {
    "tfidf__max_df": [0.95, 0.99],
    "tfidf__min_df": [2, 5],
    "tfidf__max_features": [1000, 2000],
    "tfidf__ngram_range": [(1, 1), (1, 2), (1, 3)],
    "clf__C": [0.1, 1, 10],
}

grid = GridSearchCV(pipe, param_grid, cv=5, n_jobs=-1, verbose=1)

grid.fit(glpn["train"]["excerpt"], glpn["train"]["label"])

# show best parameters
grid.best_params_
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# {'clf__C': 10,
#  'tfidf__max_df': 0.99,
#  'tfidf__max_features': 2000,
#  'tfidf__min_df': 5,
#  'tfidf__ngram_range': (1, 1)}

# %%
# show most important features
pd.DataFrame(
    grid.best_estimator_.named_steps["clf"].coef_,
    columns=grid.best_estimator_.named_steps["tfidf"].get_feature_names_out(),
).T.sort_values(0, ascending=False).head(50)
# Out:
#                                0
# demonstranten           8.927157
# kundgebung              8.420434
# demonstration           7.042979
# unterschriften          6.819035
# legida                  6.692747
# streik                  6.616384
# gegen                   6.529716
# demo                    5.549451
# bürgerbegehren          5.391450
# 2011                    4.751349
# gegner                  4.631204
# pegida                  4.327632
# protest                 4.281839
# am                      4.255427
# demonstrieren           4.244054
# protestaktion           4.062974
# teilnehmer              4.004744
# aufgerufen              3.962476
# gestern                 3.942385
# 2010                    3.773868
# studenten               3.676167
# ausstand                3.658275
# verdi                   3.521126
# durch                   3.517449
# proteste                3.462706
# lufthansa               3.420655
# veranstaltung           3.400651
# unterschriftensammlung  3.378359
# schlossplatz            3.305758
# lehrer                  3.305360
# npd                     3.299272
# gruppe                  3.269740
# gewerkschaften          3.201831
# 2012                    3.194531
# aktion                  3.185515
# deren                   3.144558
# august                  3.132134
# personen                3.051787
# beschäftigte            3.009136
# dem                     2.979634
# polizei                 2.931992
# mobil                   2.913354
# aktivisten              2.903365
# montagsdemonstration    2.899504
# studierenden            2.892287
# heute                   2.871695
# versammelt              2.869259
# protestmarsch           2.860077
# menschen                2.811678
# einigen                 2.808486

# %%
# evaluate on dev, test, test.time, test.loc
from sklearn.metrics import classification_report

for split in ["dev", "test", "test.time", "test.loc"]:
    print(split)
    print(
        classification_report(
            glpn[split]["label"], grid.predict(glpn[split]["excerpt"])
        )
    )
# Out:
# dev
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77       122
#            1       0.80      0.86      0.83       152
#
#     accuracy                           0.81       274
#    macro avg       0.81      0.80      0.80       274
# weighted avg       0.81      0.81      0.81       274
#
# test
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       217
#            1       0.89      0.87      0.88       330
#
#     accuracy                           0.85       547
#    macro avg       0.85      0.85      0.85       547
# weighted avg       0.85      0.85      0.85       547
#
# test.time
#               precision    recall  f1-score   support
#
#            0       0.55      0.77      0.64       217
#            1       0.89      0.75      0.81       535
#
#     accuracy                           0.75       752
#    macro avg       0.72      0.76      0.73       752
# weighted avg       0.79      0.75      0.76       752
#
# test.loc
#               precision    recall  f1-score   support
#
#            0       0.95      0.79      0.86       395
#            1       0.46      0.80      0.59        90
#
#     accuracy                           0.79       485
#    macro avg       0.70      0.79      0.72       485
# weighted avg       0.86      0.79      0.81       485

# %%
# create a pipeline
import optuna
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

# use hyperparameter optimization to find the best parameters
# compare bow and tfidf for feature extraction
# compare svm, decision tree, random forest, xgboost, logistic regression, ridge regression, MLP for classifier
# use dev set


def objective(trial, return_model=False, eval="split"):
    # suggest classifier
    classifier_name = trial.suggest_categorical(
        "classifier",
        [
            "SVC",
            "DecisionTreeClassifier",
            "RandomForestClassifier",
            "XGBClassifier",
            "LogisticRegression",
            "RidgeClassifier",
            "MLPClassifier",
        ],
    )
    if classifier_name == "SVC":
        # suggest parameters
        C = trial.suggest_float("C", 1e-7, 1e3, log=True)
        # create classifier
        classifier_obj = SVC(C=C)
    elif classifier_name == "DecisionTreeClassifier":
        # suggest parameters
        max_depth = trial.suggest_int("max_depth", 1, 32, log=True)
        # create classifier
        classifier_obj = DecisionTreeClassifier(max_depth=max_depth)
    elif classifier_name == "RandomForestClassifier":
        # suggest parameters
        n_estimators = trial.suggest_int("n_estimators", 1, 100)
        max_depth = trial.suggest_int("max_depth", 1, 32, log=True)
        # create classifier
        classifier_obj = RandomForestClassifier(
            n_estimators=n_estimators, max_depth=max_depth
        )
    elif classifier_name == "XGBClassifier":
        # suggest parameters
        n_estimators = trial.suggest_int("n_estimators", 1, 100)
        max_depth = trial.suggest_int("max_depth", 1, 32, log=True)
        # create classifier
        classifier_obj = XGBClassifier(n_estimators=n_estimators, max_depth=max_depth)
    if classifier_name == "LogisticRegression":
        # suggest parameters
        C = trial.suggest_float("C", 1e-7, 1e3, log=True)
        # create classifier
        classifier_obj = LogisticRegression(C=C)
    elif classifier_name == "RidgeClassifier":
        # suggest parameters
        alpha = trial.suggest_float("alpha", 1e-7, 1e3, log=True)
        # create classifier
        classifier_obj = RidgeClassifier(alpha=alpha)
    elif classifier_name == "MLPClassifier":
        # suggest parameters
        hidden_layer_sizes = trial.suggest_int("hidden_layer_sizes", 1, 20)
        # create classifier
        classifier_obj = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes)

    # suggest feature extraction
    feature_extraction_name = trial.suggest_categorical(
        "feature_extraction", ["bow", "tfidf"]
    )
    if feature_extraction_name == "bow":
        # suggest parameters
        max_features = trial.suggest_int("max_features", 8, 256, log=True)
        max_ngram = trial.suggest_int("max_ngram", 1, 5)
        # create feature extraction
        feature_extraction_obj = CountVectorizer(
            max_features=max_features, ngram_range=(1, max_ngram)
        )
    elif feature_extraction_name == "tfidf":
        # suggest parameters
        max_features = trial.suggest_int("max_features", 8, 256, log=True)
        ngram_range = trial.suggest_int("ngram_range", 1, 5)
        # create feature extraction
        feature_extraction_obj = TfidfVectorizer(
            max_features=max_features, ngram_range=(1, ngram_range)
        )
    # create pipeline
    pipe = Pipeline([("fe", feature_extraction_obj), ("clf", classifier_obj)])
    if eval == "split":
        # fit
        pipe.fit(glpn["train"]["excerpt"], glpn["train"]["label"])
        if return_model:
            return pipe
        # evaluate on dev
        y_pred = pipe.predict(glpn["dev"]["excerpt"])
        return f1_score(glpn["dev"]["label"], y_pred, average="macro")
    elif eval == "cv":
        if return_model:
            # train on all data
            pipe.fit(glpn["train"]["excerpt"], glpn["train"]["label"])
            return pipe
        # use cross validation (folding by newspaper)
        newspapers = pd.Series(glpn["train"]["newspaper"])
        splits = []
        for newspaper in newspapers.unique():
            train = newspapers != newspaper
            dev = newspapers == newspaper
            splits.append((train, dev))
        scores = cross_val_score(
            pipe,
            glpn["train"]["excerpt"],
            glpn["train"]["label"],
            cv=splits,
            scoring="f1_macro",
        )
        return scores.mean()


# create study
study = optuna.create_study(
    direction="maximize",
    storage="sqlite:///db.sqlite3",
    study_name="glpn-3",
    load_if_exists=True,
)
# optimize
study.optimize(objective, n_trials=100)
# Out:
# [I 2023-02-02 17:07:22,347] A new study created in RDB with name: glpn-3
# [I 2023-02-02 17:07:23,360] Trial 0 finished with value: 0.6278824833702882 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 98, 'max_depth': 8, 'feature_extraction': 'bow', 'max_features': 20, 'max_ngram': 2}. Best is trial 0 with value: 0.6278824833702882.
# [I 2023-02-02 17:07:24,120] Trial 1 finished with value: 0.5738122171945701 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 9, 'max_depth': 13, 'feature_extraction': 'bow', 'max_features': 13, 'max_ngram': 2}. Best is trial 0 with value: 0.6278824833702882.
# [I 2023-02-02 17:07:24,355] Trial 2 finished with value: 0.5953984839748547 and parameters: {'classifier': 'LogisticRegression', 'C': 38.676169436150005, 'feature_extraction': 'bow', 'max_features': 30, 'max_ngram': 1}. Best is trial 0 with value: 0.6278824833702882.
# [I 2023-02-02 17:07:27,430] Trial 3 finished with value: 0.7118744607420189 and parameters: {'classifier': 'RidgeClassifier', 'alpha': 2.0901420982767305, 'feature_extraction': 'bow', 'max_features': 164, 'max_ngram': 5}. Best is trial 3 with value: 0.7118744607420189.
# [I 2023-02-02 17:07:28,994] Trial 4 finished with value: 0.6076482479784368 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 67, 'max_depth': 2, 'feature_extraction': 'tfidf', 'max_features': 19, 'ngram_range': 3}. Best is trial 3 with value: 0.7118744607420189.
# [I 2023-02-02 17:07:29,765] Trial 5 finished with value: 0.6767567417523699 and parameters: {'classifier': 'DecisionTreeClassifier', 'max_depth': 2, 'feature_extraction': 'tfidf', 'max_features': 233, 'ngram_range': 2}. Best is trial 3 with value: 0.7118744607420189.
# [I 2023-02-02 17:07:30,515] Trial 6 finished with value: 0.6525024363544129 and parameters: {'classifier': 'DecisionTreeClassifier', 'max_depth': 1, 'feature_extraction': 'tfidf', 'max_features': 22, 'ngram_range': 2}. Best is trial 3 with value: 0.7118744607420189.
# /Users/david/Repositories/protest-impact/.venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-02-02 17:07:33,261] Trial 7 finished with value: 0.7658024339614962 and parameters: {'classifier': 'MLPClassifier', 'hidden_layer_sizes': 8, 'feature_extraction': 'bow', 'max_features': 234, 'max_ngram': 4}. Best is trial 7 with value: 0.7658024339614962.
# [I 2023-02-02 17:07:37,140] Trial 8 finished with value: 0.7646174496644296 and parameters: {'classifier': 'SVC', 'C': 2.537394402343021, 'feature_extraction': 'tfidf', 'max_features': 164, 'ngram_range': 5}. Best is trial 7 with value: 0.7658024339614962.
# [I 2023-02-02 17:07:38,587] Trial 9 finished with value: 0.6294167371090449 and parameters: {'classifier': 'LogisticRegression', 'C': 1.7110934825748545, 'feature_extraction': 'bow', 'max_features': 25, 'max_ngram': 3}. Best is trial 7 with value: 0.7658024339614962.
# /Users/david/Repositories/protest-impact/.venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-02-02 17:07:41,985] Trial 10 finished with value: 0.6549739161719734 and parameters: {'classifier': 'MLPClassifier', 'hidden_layer_sizes': 8, 'feature_extraction': 'bow', 'max_features': 61, 'max_ngram': 5}. Best is trial 7 with value: 0.7658024339614962.
# [I 2023-02-02 17:07:45,830] Trial 11 finished with value: 0.3568075117370892 and parameters: {'classifier': 'SVC', 'C': 9.096407969500192e-06, 'feature_extraction': 'tfidf', 'max_features': 126, 'ngram_range': 5}. Best is trial 7 with value: 0.7658024339614962.
# /Users/david/Repositories/protest-impact/.venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-02-02 17:07:49,305] Trial 12 finished with value: 0.7143166646355499 and parameters: {'classifier': 'MLPClassifier', 'hidden_layer_sizes': 16, 'feature_extraction': 'tfidf', 'max_features': 95, 'ngram_range': 5}. Best is trial 7 with value: 0.7658024339614962.
# [I 2023-02-02 17:07:51,608] Trial 13 finished with value: 0.678678038379531 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 2, 'max_depth': 24, 'feature_extraction': 'tfidf', 'max_features': 237, 'ngram_range': 4}. Best is trial 7 with value: 0.7658024339614962.
# [I 2023-02-02 17:07:54,597] Trial 14 finished with value: 0.3568075117370892 and parameters: {'classifier': 'SVC', 'C': 0.008439680674659297, 'feature_extraction': 'bow', 'max_features': 75, 'max_ngram': 4}. Best is trial 7 with value: 0.7658024339614962.
# /Users/david/Repositories/protest-impact/.venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-02-02 17:07:55,158] Trial 15 finished with value: 0.744909937259664 and parameters: {'classifier': 'MLPClassifier', 'hidden_layer_sizes': 1, 'feature_extraction': 'tfidf', 'max_features': 143, 'ngram_range': 1}. Best is trial 7 with value: 0.7658024339614962.
# [I 2023-02-02 17:07:58,182] Trial 16 finished with value: 0.6526675485008819 and parameters: {'classifier': 'SVC', 'C': 999.0452485976836, 'feature_extraction': 'bow', 'max_features': 43, 'max_ngram': 4}. Best is trial 7 with value: 0.7658024339614962.
# [I 2023-02-02 17:08:00,758] Trial 17 finished with value: 0.7787025502730969 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 42, 'max_depth': 32, 'feature_extraction': 'tfidf', 'max_features': 253, 'ngram_range': 4}. Best is trial 17 with value: 0.7787025502730969.
# [I 2023-02-02 17:08:03,384] Trial 18 finished with value: 0.7740889353047875 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 49, 'max_depth': 26, 'feature_extraction': 'bow', 'max_features': 238, 'max_ngram': 4}. Best is trial 17 with value: 0.7787025502730969.
# [I 2023-02-02 17:08:05,123] Trial 19 finished with value: 0.7631026390547162 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 45, 'max_depth': 32, 'feature_extraction': 'tfidf', 'max_features': 107, 'ngram_range': 3}. Best is trial 17 with value: 0.7787025502730969.
# [I 2023-02-02 17:08:06,757] Trial 20 finished with value: 0.7281746031746033 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 47, 'max_depth': 32, 'feature_extraction': 'bow', 'max_features': 77, 'max_ngram': 3}. Best is trial 17 with value: 0.7787025502730969.
# [I 2023-02-02 17:08:09,217] Trial 21 finished with value: 0.7862041587384156 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 30, 'max_depth': 10, 'feature_extraction': 'bow', 'max_features': 243, 'max_ngram': 4}. Best is trial 21 with value: 0.7862041587384156.
# [I 2023-02-02 17:08:11,805] Trial 22 finished with value: 0.772273315620955 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 32, 'max_depth': 12, 'feature_extraction': 'bow', 'max_features': 183, 'max_ngram': 4}. Best is trial 21 with value: 0.7862041587384156.
# [I 2023-02-02 17:08:15,419] Trial 23 finished with value: 0.7946726616254514 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 29, 'max_depth': 16, 'feature_extraction': 'bow', 'max_features': 238, 'max_ngram': 5}. Best is trial 23 with value: 0.7946726616254514.
# [I 2023-02-02 17:08:18,591] Trial 24 finished with value: 0.7998376623376624 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 26, 'max_depth': 7, 'feature_extraction': 'bow', 'max_features': 131, 'max_ngram': 5}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:21,627] Trial 25 finished with value: 0.7542600896860985 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 21, 'max_depth': 6, 'feature_extraction': 'bow', 'max_features': 121, 'max_ngram': 5}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:24,718] Trial 26 finished with value: 0.7370619162825902 and parameters: {'classifier': 'RidgeClassifier', 'alpha': 2.651328047345551e-07, 'feature_extraction': 'bow', 'max_features': 171, 'max_ngram': 5}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:27,899] Trial 27 finished with value: 0.7486961164118218 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 23, 'max_depth': 12, 'feature_extraction': 'bow', 'max_features': 130, 'max_ngram': 5}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:30,991] Trial 28 finished with value: 0.7728403249875643 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 25, 'max_depth': 5, 'feature_extraction': 'bow', 'max_features': 185, 'max_ngram': 5}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:33,442] Trial 29 finished with value: 0.7837116881702869 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 68, 'max_depth': 8, 'feature_extraction': 'bow', 'max_features': 95, 'max_ngram': 4}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:36,720] Trial 30 finished with value: 0.774671052631579 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 32, 'max_depth': 16, 'feature_extraction': 'bow', 'max_features': 187, 'max_ngram': 5}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:39,513] Trial 31 finished with value: 0.7721729490022173 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 65, 'max_depth': 9, 'feature_extraction': 'bow', 'max_features': 104, 'max_ngram': 4}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:41,262] Trial 32 finished with value: 0.7713347332148819 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 65, 'max_depth': 7, 'feature_extraction': 'bow', 'max_features': 138, 'max_ngram': 3}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:43,902] Trial 33 finished with value: 0.727757906092091 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 89, 'max_depth': 4, 'feature_extraction': 'bow', 'max_features': 202, 'max_ngram': 4}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:47,086] Trial 34 finished with value: 0.3568075117370892 and parameters: {'classifier': 'LogisticRegression', 'C': 4.1485592773422324e-07, 'feature_extraction': 'bow', 'max_features': 148, 'max_ngram': 5}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:49,455] Trial 35 finished with value: 0.7118744607420189 and parameters: {'classifier': 'RidgeClassifier', 'alpha': 83.22066518331987, 'feature_extraction': 'bow', 'max_features': 152, 'max_ngram': 4}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:50,969] Trial 36 finished with value: 0.5018250961124758 and parameters: {'classifier': 'DecisionTreeClassifier', 'max_depth': 16, 'feature_extraction': 'bow', 'max_features': 8, 'max_ngram': 3}. Best is trial 24 with value: 0.7998376623376624.
# [I 2023-02-02 17:08:54,060] Trial 37 finished with value: 0.8013959731543625 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 14, 'max_depth': 9, 'feature_extraction': 'bow', 'max_features': 210, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:08:57,186] Trial 38 finished with value: 0.757868261844878 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 12, 'max_depth': 18, 'feature_extraction': 'bow', 'max_features': 206, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:00,916] Trial 39 finished with value: 0.7736794356203709 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 33, 'max_depth': 10, 'feature_extraction': 'bow', 'max_features': 253, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:04,106] Trial 40 finished with value: 0.7709771354616048 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 12, 'max_depth': 10, 'feature_extraction': 'bow', 'max_features': 207, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:06,639] Trial 41 finished with value: 0.7775974025974026 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 16, 'max_depth': 8, 'feature_extraction': 'bow', 'max_features': 158, 'max_ngram': 4}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:10,257] Trial 42 finished with value: 0.7709771354616048 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 80, 'max_depth': 6, 'feature_extraction': 'bow', 'max_features': 208, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:11,001] Trial 43 finished with value: 0.6472378277153558 and parameters: {'classifier': 'LogisticRegression', 'C': 0.0008683921491661216, 'feature_extraction': 'bow', 'max_features': 172, 'max_ngram': 2}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:13,312] Trial 44 finished with value: 0.7422043010752688 and parameters: {'classifier': 'DecisionTreeClassifier', 'max_depth': 10, 'feature_extraction': 'bow', 'max_features': 114, 'max_ngram': 4}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:13,581] Trial 45 finished with value: 0.7554507203876069 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 37, 'max_depth': 5, 'feature_extraction': 'bow', 'max_features': 214, 'max_ngram': 1}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:15,043] Trial 46 finished with value: 0.7301221075355866 and parameters: {'classifier': 'RidgeClassifier', 'alpha': 9.518092691379947e-05, 'feature_extraction': 'bow', 'max_features': 160, 'max_ngram': 3}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:18,247] Trial 47 finished with value: 0.7990547588005216 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 60, 'max_depth': 8, 'feature_extraction': 'bow', 'max_features': 134, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:21,571] Trial 48 finished with value: 0.7527042500168385 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 59, 'max_depth': 14, 'feature_extraction': 'bow', 'max_features': 141, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# /Users/david/Repositories/protest-impact/.venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-02-02 17:09:25,413] Trial 49 finished with value: 0.7573404182846242 and parameters: {'classifier': 'MLPClassifier', 'hidden_layer_sizes': 20, 'feature_extraction': 'bow', 'max_features': 229, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:28,605] Trial 50 finished with value: 0.7981776516804888 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 55, 'max_depth': 20, 'feature_extraction': 'bow', 'max_features': 181, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:31,811] Trial 51 finished with value: 0.7946726616254514 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 57, 'max_depth': 19, 'feature_extraction': 'bow', 'max_features': 197, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:34,984] Trial 52 finished with value: 0.7896929824561403 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 54, 'max_depth': 19, 'feature_extraction': 'bow', 'max_features': 179, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:38,193] Trial 53 finished with value: 0.75902819765844 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 56, 'max_depth': 19, 'feature_extraction': 'bow', 'max_features': 120, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:39,246] Trial 54 finished with value: 0.3568075117370892 and parameters: {'classifier': 'SVC', 'C': 0.00012612260109663774, 'feature_extraction': 'tfidf', 'max_features': 133, 'ngram_range': 1}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:42,520] Trial 55 finished with value: 0.7821820175438596 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 60, 'max_depth': 14, 'feature_extraction': 'bow', 'max_features': 197, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:45,991] Trial 56 finished with value: 0.3568075117370892 and parameters: {'classifier': 'LogisticRegression', 'C': 1.0417794022253409e-07, 'feature_extraction': 'bow', 'max_features': 164, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:46,744] Trial 57 finished with value: 0.7473959408324734 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 5, 'max_depth': 22, 'feature_extraction': 'tfidf', 'max_features': 255, 'ngram_range': 2}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:49,919] Trial 58 finished with value: 0.704948042857912 and parameters: {'classifier': 'DecisionTreeClassifier', 'max_depth': 14, 'feature_extraction': 'bow', 'max_features': 144, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:09:53,184] Trial 59 finished with value: 0.770017199862401 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 40, 'max_depth': 24, 'feature_extraction': 'bow', 'max_features': 224, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# /Users/david/Repositories/protest-impact/.venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-02-02 17:09:56,961] Trial 60 finished with value: 0.7682780445220427 and parameters: {'classifier': 'MLPClassifier', 'hidden_layer_sizes': 2, 'feature_extraction': 'bow', 'max_features': 185, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:00,392] Trial 61 finished with value: 0.7659281305114638 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 54, 'max_depth': 20, 'feature_extraction': 'bow', 'max_features': 178, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:03,730] Trial 62 finished with value: 0.7561977248771405 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 77, 'max_depth': 17, 'feature_extraction': 'bow', 'max_features': 162, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:07,066] Trial 63 finished with value: 0.7797397642891204 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 52, 'max_depth': 22, 'feature_extraction': 'bow', 'max_features': 226, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:10,693] Trial 64 finished with value: 0.7787025502730969 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 73, 'max_depth': 13, 'feature_extraction': 'bow', 'max_features': 192, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:14,085] Trial 65 finished with value: 0.7636993333424593 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 61, 'max_depth': 25, 'feature_extraction': 'bow', 'max_features': 126, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:17,387] Trial 66 finished with value: 0.3568075117370892 and parameters: {'classifier': 'SVC', 'C': 0.03011357030300991, 'feature_extraction': 'tfidf', 'max_features': 171, 'ngram_range': 4}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:20,778] Trial 67 finished with value: 0.7821820175438596 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 48, 'max_depth': 18, 'feature_extraction': 'bow', 'max_features': 110, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:23,990] Trial 68 finished with value: 0.7498739696164589 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 19, 'max_depth': 27, 'feature_extraction': 'bow', 'max_features': 151, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:24,749] Trial 69 finished with value: 0.7518753294497682 and parameters: {'classifier': 'RidgeClassifier', 'alpha': 0.01957996389576989, 'feature_extraction': 'bow', 'max_features': 230, 'max_ngram': 2}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:27,464] Trial 70 finished with value: 0.7692850934376358 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 51, 'max_depth': 12, 'feature_extraction': 'bow', 'max_features': 188, 'max_ngram': 4}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:29,949] Trial 71 finished with value: 0.7717508569243585 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 26, 'max_depth': 10, 'feature_extraction': 'bow', 'max_features': 216, 'max_ngram': 4}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:33,167] Trial 72 finished with value: 0.7792344353858549 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 42, 'max_depth': 16, 'feature_extraction': 'bow', 'max_features': 252, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:35,638] Trial 73 finished with value: 0.7792344353858549 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 28, 'max_depth': 12, 'feature_extraction': 'bow', 'max_features': 204, 'max_ngram': 4}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:38,892] Trial 74 finished with value: 0.7872062129572859 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 17, 'max_depth': 20, 'feature_extraction': 'bow', 'max_features': 173, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:41,958] Trial 75 finished with value: 0.7697478991596638 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 17, 'max_depth': 21, 'feature_extraction': 'bow', 'max_features': 137, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:44,971] Trial 76 finished with value: 0.701003928415539 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 3, 'max_depth': 28, 'feature_extraction': 'bow', 'max_features': 171, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:48,232] Trial 77 finished with value: 0.7872062129572859 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 57, 'max_depth': 20, 'feature_extraction': 'bow', 'max_features': 150, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:48,559] Trial 78 finished with value: 0.785394047426133 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 10, 'max_depth': 15, 'feature_extraction': 'tfidf', 'max_features': 126, 'ngram_range': 1}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:51,587] Trial 79 finished with value: 0.3568075117370892 and parameters: {'classifier': 'LogisticRegression', 'C': 7.934107680834512e-06, 'feature_extraction': 'bow', 'max_features': 192, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:54,633] Trial 80 finished with value: 0.7118744607420189 and parameters: {'classifier': 'DecisionTreeClassifier', 'max_depth': 17, 'feature_extraction': 'bow', 'max_features': 97, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:10:57,979] Trial 81 finished with value: 0.7636993333424593 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 59, 'max_depth': 20, 'feature_extraction': 'bow', 'max_features': 147, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:01,542] Trial 82 finished with value: 0.7951192984841275 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 54, 'max_depth': 22, 'feature_extraction': 'bow', 'max_features': 155, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:01,925] Trial 83 finished with value: 0.7907027498908773 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 45, 'max_depth': 29, 'feature_extraction': 'bow', 'max_features': 171, 'max_ngram': 1}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:02,785] Trial 84 finished with value: 0.7671600877192982 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 46, 'max_depth': 29, 'feature_extraction': 'bow', 'max_features': 211, 'max_ngram': 2}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:03,205] Trial 85 finished with value: 0.7990547588005216 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 63, 'max_depth': 25, 'feature_extraction': 'bow', 'max_features': 134, 'max_ngram': 1}. Best is trial 37 with value: 0.8013959731543625.
# /Users/david/Repositories/protest-impact/.venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-02-02 17:11:03,949] Trial 86 finished with value: 0.7705936369037973 and parameters: {'classifier': 'MLPClassifier', 'hidden_layer_sizes': 13, 'feature_extraction': 'bow', 'max_features': 117, 'max_ngram': 1}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:04,403] Trial 87 finished with value: 0.7424075209482934 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 68, 'max_depth': 31, 'feature_extraction': 'bow', 'max_features': 86, 'max_ngram': 1}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:04,832] Trial 88 finished with value: 0.773237277327798 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 64, 'max_depth': 25, 'feature_extraction': 'bow', 'max_features': 130, 'max_ngram': 1}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:05,838] Trial 89 finished with value: 0.6660788277632013 and parameters: {'classifier': 'SVC', 'C': 0.14463171577348774, 'feature_extraction': 'bow', 'max_features': 133, 'max_ngram': 1}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:06,062] Trial 90 finished with value: 0.7355176398613283 and parameters: {'classifier': 'RidgeClassifier', 'alpha': 386.10419204885926, 'feature_extraction': 'bow', 'max_features': 157, 'max_ngram': 1}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:07,776] Trial 91 finished with value: 0.7712009418077781 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 53, 'max_depth': 24, 'feature_extraction': 'bow', 'max_features': 179, 'max_ngram': 3}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:08,170] Trial 92 finished with value: 0.7802188838284279 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 55, 'max_depth': 32, 'feature_extraction': 'bow', 'max_features': 192, 'max_ngram': 1}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:09,093] Trial 93 finished with value: 0.7486961164118218 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 62, 'max_depth': 27, 'feature_extraction': 'bow', 'max_features': 160, 'max_ngram': 2}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:12,500] Trial 94 finished with value: 0.7931406384814494 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 37, 'max_depth': 23, 'feature_extraction': 'bow', 'max_features': 234, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:15,911] Trial 95 finished with value: 0.7892734264318964 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 34, 'max_depth': 23, 'feature_extraction': 'bow', 'max_features': 233, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:19,291] Trial 96 finished with value: 0.7709771354616048 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 39, 'max_depth': 28, 'feature_extraction': 'bow', 'max_features': 241, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:22,631] Trial 97 finished with value: 0.7783649698015531 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 43, 'max_depth': 23, 'feature_extraction': 'bow', 'max_features': 222, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:24,532] Trial 98 finished with value: 0.7464205999237845 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 35, 'max_depth': 17, 'feature_extraction': 'tfidf', 'max_features': 201, 'ngram_range': 3}. Best is trial 37 with value: 0.8013959731543625.
# [I 2023-02-02 17:11:27,642] Trial 99 finished with value: 0.7857528041415013 and parameters: {'classifier': 'XGBClassifier', 'n_estimators': 23, 'max_depth': 9, 'feature_extraction': 'bow', 'max_features': 256, 'max_ngram': 5}. Best is trial 37 with value: 0.8013959731543625.

# %%
# show best parameters
study.best_params
# Out:
# {'classifier': 'XGBClassifier',
#  'feature_extraction': 'tfidf',
#  'max_depth': 32,
#  'max_features': 702,
#  'n_estimators': 73,
#  'ngram_range': 2}

# %%
# show best score
study.best_value
# Out:
# 0.8377214235718516

# %%
model = objective(study.best_trial, return_model=True)

# %%
# evaluate on test.time, and test.loc set

from sklearn.metrics import classification_report

for split in ["test", "test.time", "test.loc"]:
    print(split)
    print(
        classification_report(
            glpn[split]["label"], model.predict(glpn[split]["excerpt"])
        )
    )
# Out:
# test
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       217
#            1       0.86      0.88      0.87       330
#
#     accuracy                           0.84       547
#    macro avg       0.83      0.83      0.83       547
# weighted avg       0.84      0.84      0.84       547
#
# test.time
#               precision    recall  f1-score   support
#
#            0       0.57      0.83      0.67       217
#            1       0.91      0.74      0.82       535
#
#     accuracy                           0.77       752
#    macro avg       0.74      0.79      0.75       752
# weighted avg       0.81      0.77      0.78       752
#
# test.loc
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91       395
#            1       0.59      0.61      0.60        90
#
#     accuracy                           0.85       485
#    macro avg       0.75      0.76      0.75       485
# weighted avg       0.85      0.85      0.85       485

# %%
from collections import Counter

for split in ["train", "dev", "test", "test.time", "test.loc"]:
    print(split)
    print(Counter(glpn[split]["newspaper"]))
    print(Counter(glpn[split]["label"]))
# Out:
# train
# Counter({'Stuttgarter Zeitung': 1280, 'Leipziger Volkszeitung': 517, 'Weser Kurier': 117})
# Counter({1: 1117, 0: 797})
# dev
# Counter({'Stuttgarter Zeitung': 187, 'Leipziger Volkszeitung': 69, 'Weser Kurier': 18})
# Counter({1: 152, 0: 122})
# test
# Counter({'Stuttgarter Zeitung': 365, 'Leipziger Volkszeitung': 143, 'Weser Kurier': 39})
# Counter({1: 330, 0: 217})
# test.time
# Counter({'Leipziger Volkszeitung': 391, 'Weser Kurier': 361})
# Counter({1: 535, 0: 217})
# test.loc
# Counter({'Sächsische Zeitung': 485})
# Counter({0: 395, 1: 90})

# %%
# use cross validation

study = optuna.create_study(
    direction="maximize",
    storage="sqlite:///db.sqlite3",
    study_name="glpn.cv",
    load_if_exists=True,
)
# optimize
# study.optimize(partial(objective, eval="cv"), n_trials=100)
# Out:
# [I 2023-02-02 16:07:24,297] Using an existing study with name 'glpn.cv' instead of creating a new one.

# %%
# show best parameters
study.best_params
# Out:
# {'C': 4.602833645797326,
#  'classifier': 'LogisticRegression',
#  'feature_extraction': 'tfidf',
#  'max_features': 669,
#  'ngram_range': 1}

# %%
# show best score
study.best_value
# Out:
# 0.7476544079909743

# %%
# evaluate on test, test.time, and test.loc set

model = objective(study.best_trial, return_model=True, eval="cv")

for split in ["test", "test.time", "test.loc"]:
    print(split)
    print(
        classification_report(
            glpn[split]["label"], model.predict(glpn[split]["excerpt"])
        )
    )
# Out:
# test
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       217
#            1       0.86      0.88      0.87       330
#
#     accuracy                           0.84       547
#    macro avg       0.83      0.83      0.83       547
# weighted avg       0.84      0.84      0.84       547
#
# test.time
#               precision    recall  f1-score   support
#
#            0       0.56      0.78      0.66       217
#            1       0.90      0.75      0.82       535
#
#     accuracy                           0.76       752
#    macro avg       0.73      0.77      0.74       752
# weighted avg       0.80      0.76      0.77       752
#
# test.loc
#               precision    recall  f1-score   support
#
#            0       0.94      0.75      0.83       395
#            1       0.42      0.80      0.55        90
#
#     accuracy                           0.76       485
#    macro avg       0.68      0.77      0.69       485
# weighted avg       0.85      0.76      0.78       485
