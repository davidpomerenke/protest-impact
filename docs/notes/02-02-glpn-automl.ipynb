# %% [markdown]
# # Trying AutoML for protest event detection

# %% [markdown]
# To be run with Python 3.9, dependencies not included in the Poetry project.

# %%
import pandas as pd

glpn_path = "../../datasets/glpn_v1.1/"
data_files = {
    "train": str(glpn_path + "glpn_train.csv"),
    "dev": str(glpn_path + "glpn_dev.csv"),
    "test": str(glpn_path + "glpn_test.csv"),
    "test.time": str(glpn_path + "glpn_test-time.csv"),
    "test.loc": str(glpn_path + "glpn_test-loc.csv"),
}
glpn = {k: pd.read_csv(v) for k, v in data_files.items()}
# convert the "label" column to 0 and 1 instead of "irrelevant" and "relevant" in each dataset
for k, v in glpn.items():
    v["label"] = v["labels"].apply(lambda x: 0 if x == "irrelevant" else 1)

# %%
glpn["train"].head()
# Out:
#    id               newspaper      labels    year  \
# 0   1     Stuttgarter Zeitung    relevant  2010.0
# 1   3     Stuttgarter Zeitung    relevant  2010.0
# 2   4  Leipziger Volkszeitung  irrelevant  2015.0
# 3   5  Leipziger Volkszeitung  irrelevant  2015.0
# 4   6  Leipziger Volkszeitung  irrelevant  2015.0
#
#                                              excerpt  label
# 0  Stuttgarter Zeitung 2010-07-06 Parkschützer st...      1
# 1  Stuttgarter Zeitung 2010-08-27 DER SCHWABENSTR...      1
# 2  "Ohne uns hätte es keinen Wiederaufbau gegeben...      0
# 3  Mini-Meisterschaft im ATSV-Stadion Wurzen. Ein...      0
# 4  Kurstädter von energischem Einsatz beeindruckt...      0

# %%
from pycaret.nlp import *

# initialize the setup
nlp1 = setup(data=glpn["train"], target="excerpt")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9df37">
#   <thead>
#     <tr>
#       <th id="T_9df37_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9df37_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9df37_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_9df37_row0_col1" class="data row0 col1" >5283</td>
#     </tr>
#     <tr>
#       <td id="T_9df37_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_9df37_row1_col1" class="data row1 col1" >1914</td>
#     </tr>
#     <tr>
#       <td id="T_9df37_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_9df37_row2_col1" class="data row2 col1" >12898</td>
#     </tr>
#     <tr>
#       <td id="T_9df37_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_9df37_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.classification import *
from sklearn.metrics import f1_score

# train the model
clf = setup(
    data=glpn["train"],
    target="label",
    text_features=["excerpt"],
    ignore_features=["labels", "newspaper", "year", "id"],
    test_data=glpn["dev"],
)
# Out:
# <style type="text/css">
# #T_5f998_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5f998">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f998_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5f998_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f998_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f998_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5f998_row0_col1" class="data row0 col1" >7043</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f998_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5f998_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5f998_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5f998_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5f998_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5f998_row3_col1" class="data row3 col1" >(2188, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5f998_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5f998_row4_col1" class="data row4 col1" >(2188, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5f998_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5f998_row5_col1" class="data row5 col1" >(1914, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5f998_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5f998_row6_col1" class="data row6 col1" >(274, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5f998_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_5f998_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5f998_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_5f998_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5f998_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_5f998_row9_col1" class="data row9 col1" >12.9%</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5f998_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_5f998_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5f998_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_5f998_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5f998_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_5f998_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5f998_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_5f998_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5f998_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_5f998_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5f998_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_5f998_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5f998_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_5f998_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5f998_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_5f998_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5f998_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_5f998_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5f998_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_5f998_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5f998_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5f998_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_5f998_row20_col1" class="data row20 col1" >91e3</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models(sort="F1")
# Out:
# <style type="text/css">
# #T_d1096 th {
#   text-align: left;
# }
# #T_d1096_row0_col0, #T_d1096_row0_col1, #T_d1096_row0_col2, #T_d1096_row0_col3, #T_d1096_row0_col4, #T_d1096_row0_col6, #T_d1096_row0_col7, #T_d1096_row1_col0, #T_d1096_row1_col1, #T_d1096_row1_col2, #T_d1096_row1_col3, #T_d1096_row1_col4, #T_d1096_row1_col5, #T_d1096_row1_col6, #T_d1096_row1_col7, #T_d1096_row2_col0, #T_d1096_row2_col1, #T_d1096_row2_col2, #T_d1096_row2_col3, #T_d1096_row2_col4, #T_d1096_row2_col5, #T_d1096_row2_col6, #T_d1096_row2_col7, #T_d1096_row3_col0, #T_d1096_row3_col1, #T_d1096_row3_col2, #T_d1096_row3_col3, #T_d1096_row3_col4, #T_d1096_row3_col5, #T_d1096_row3_col6, #T_d1096_row3_col7, #T_d1096_row4_col0, #T_d1096_row4_col1, #T_d1096_row4_col2, #T_d1096_row4_col3, #T_d1096_row4_col4, #T_d1096_row4_col5, #T_d1096_row4_col6, #T_d1096_row4_col7, #T_d1096_row5_col0, #T_d1096_row5_col3, #T_d1096_row5_col4, #T_d1096_row5_col5, #T_d1096_row6_col0, #T_d1096_row6_col1, #T_d1096_row6_col2, #T_d1096_row6_col3, #T_d1096_row6_col4, #T_d1096_row6_col5, #T_d1096_row6_col6, #T_d1096_row6_col7, #T_d1096_row7_col0, #T_d1096_row7_col1, #T_d1096_row7_col2, #T_d1096_row7_col4, #T_d1096_row7_col5, #T_d1096_row7_col6, #T_d1096_row7_col7, #T_d1096_row8_col0, #T_d1096_row8_col1, #T_d1096_row8_col2, #T_d1096_row8_col3, #T_d1096_row8_col5, #T_d1096_row8_col6, #T_d1096_row8_col7, #T_d1096_row9_col0, #T_d1096_row9_col1, #T_d1096_row9_col2, #T_d1096_row9_col3, #T_d1096_row9_col4, #T_d1096_row9_col5, #T_d1096_row9_col6, #T_d1096_row9_col7, #T_d1096_row10_col0, #T_d1096_row10_col1, #T_d1096_row10_col2, #T_d1096_row10_col3, #T_d1096_row10_col4, #T_d1096_row10_col5, #T_d1096_row10_col6, #T_d1096_row10_col7, #T_d1096_row11_col0, #T_d1096_row11_col1, #T_d1096_row11_col2, #T_d1096_row11_col3, #T_d1096_row11_col4, #T_d1096_row11_col5, #T_d1096_row11_col6, #T_d1096_row11_col7, #T_d1096_row12_col0, #T_d1096_row12_col1, #T_d1096_row12_col2, #T_d1096_row12_col3, #T_d1096_row12_col4, #T_d1096_row12_col5, #T_d1096_row12_col6, #T_d1096_row12_col7, #T_d1096_row13_col0, #T_d1096_row13_col1, #T_d1096_row13_col2, #T_d1096_row13_col3, #T_d1096_row13_col4, #T_d1096_row13_col5, #T_d1096_row13_col6, #T_d1096_row13_col7 {
#   text-align: left;
# }
# #T_d1096_row0_col5, #T_d1096_row5_col1, #T_d1096_row5_col2, #T_d1096_row5_col6, #T_d1096_row5_col7, #T_d1096_row7_col3, #T_d1096_row8_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d1096_row0_col8, #T_d1096_row1_col8, #T_d1096_row2_col8, #T_d1096_row3_col8, #T_d1096_row4_col8, #T_d1096_row5_col8, #T_d1096_row6_col8, #T_d1096_row8_col8, #T_d1096_row9_col8, #T_d1096_row10_col8, #T_d1096_row11_col8, #T_d1096_row12_col8, #T_d1096_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d1096_row7_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d1096">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1096_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d1096_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d1096_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d1096_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d1096_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d1096_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d1096_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d1096_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_d1096_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1096_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_d1096_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_d1096_row0_col1" class="data row0 col1" >0.6673</td>
#       <td id="T_d1096_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_d1096_row0_col3" class="data row0 col3" >0.8415</td>
#       <td id="T_d1096_row0_col4" class="data row0 col4" >0.6745</td>
#       <td id="T_d1096_row0_col5" class="data row0 col5" >0.7471</td>
#       <td id="T_d1096_row0_col6" class="data row0 col6" >0.2769</td>
#       <td id="T_d1096_row0_col7" class="data row0 col7" >0.2937</td>
#       <td id="T_d1096_row0_col8" class="data row0 col8" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_d1096_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_d1096_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_d1096_row1_col1" class="data row1 col1" >0.6667</td>
#       <td id="T_d1096_row1_col2" class="data row1 col2" >0.6708</td>
#       <td id="T_d1096_row1_col3" class="data row1 col3" >0.8388</td>
#       <td id="T_d1096_row1_col4" class="data row1 col4" >0.6750</td>
#       <td id="T_d1096_row1_col5" class="data row1 col5" >0.7462</td>
#       <td id="T_d1096_row1_col6" class="data row1 col6" >0.2764</td>
#       <td id="T_d1096_row1_col7" class="data row1 col7" >0.2927</td>
#       <td id="T_d1096_row1_col8" class="data row1 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_d1096_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_d1096_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_d1096_row2_col1" class="data row2 col1" >0.6657</td>
#       <td id="T_d1096_row2_col2" class="data row2 col2" >0.6707</td>
#       <td id="T_d1096_row2_col3" class="data row2 col3" >0.8370</td>
#       <td id="T_d1096_row2_col4" class="data row2 col4" >0.6743</td>
#       <td id="T_d1096_row2_col5" class="data row2 col5" >0.7452</td>
#       <td id="T_d1096_row2_col6" class="data row2 col6" >0.2745</td>
#       <td id="T_d1096_row2_col7" class="data row2 col7" >0.2901</td>
#       <td id="T_d1096_row2_col8" class="data row2 col8" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_d1096_level0_row3" class="row_heading level0 row3" >svm</th>
#       <td id="T_d1096_row3_col0" class="data row3 col0" >SVM - Linear Kernel</td>
#       <td id="T_d1096_row3_col1" class="data row3 col1" >0.6396</td>
#       <td id="T_d1096_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_d1096_row3_col3" class="data row3 col3" >0.9070</td>
#       <td id="T_d1096_row3_col4" class="data row3 col4" >0.6349</td>
#       <td id="T_d1096_row3_col5" class="data row3 col5" >0.7443</td>
#       <td id="T_d1096_row3_col6" class="data row3 col6" >0.1875</td>
#       <td id="T_d1096_row3_col7" class="data row3 col7" >0.2397</td>
#       <td id="T_d1096_row3_col8" class="data row3 col8" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_d1096_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_d1096_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_d1096_row4_col1" class="data row4 col1" >0.6647</td>
#       <td id="T_d1096_row4_col2" class="data row4 col2" >0.7009</td>
#       <td id="T_d1096_row4_col3" class="data row4 col3" >0.8289</td>
#       <td id="T_d1096_row4_col4" class="data row4 col4" >0.6764</td>
#       <td id="T_d1096_row4_col5" class="data row4 col5" >0.7428</td>
#       <td id="T_d1096_row4_col6" class="data row4 col6" >0.2741</td>
#       <td id="T_d1096_row4_col7" class="data row4 col7" >0.2872</td>
#       <td id="T_d1096_row4_col8" class="data row4 col8" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_d1096_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_d1096_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_d1096_row5_col1" class="data row5 col1" >0.6699</td>
#       <td id="T_d1096_row5_col2" class="data row5 col2" >0.7031</td>
#       <td id="T_d1096_row5_col3" class="data row5 col3" >0.8146</td>
#       <td id="T_d1096_row5_col4" class="data row5 col4" >0.6858</td>
#       <td id="T_d1096_row5_col5" class="data row5 col5" >0.7428</td>
#       <td id="T_d1096_row5_col6" class="data row5 col6" >0.2909</td>
#       <td id="T_d1096_row5_col7" class="data row5 col7" >0.2999</td>
#       <td id="T_d1096

# %%
tuned_best = tune_model(best, optimize="F1")
# Out:
# <style type="text/css">
# #T_a7011_row10_col0, #T_a7011_row10_col1, #T_a7011_row10_col2, #T_a7011_row10_col3, #T_a7011_row10_col4, #T_a7011_row10_col5, #T_a7011_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a7011">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7011_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a7011_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a7011_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a7011_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a7011_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a7011_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a7011_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7011_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7011_row0_col0" class="data row0 col0" >0.8438</td>
#       <td id="T_a7011_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_a7011_row0_col2" class="data row0 col2" >0.9196</td>
#       <td id="T_a7011_row0_col3" class="data row0 col3" >0.8306</td>
#       <td id="T_a7011_row0_col4" class="data row0 col4" >0.8729</td>
#       <td id="T_a7011_row0_col5" class="data row0 col5" >0.6715</td>
#       <td id="T_a7011_row0_col6" class="data row0 col6" >0.6774</td>
#     </tr>
#     <tr>
#       <th id="T_a7011_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7011_row1_col0" class="data row1 col0" >0.7865</td>
#       <td id="T_a7011_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_a7011_row1_col2" class="data row1 col2" >0.8839</td>
#       <td id="T_a7011_row1_col3" class="data row1 col3" >0.7795</td>
#       <td id="T_a7011_row1_col4" class="data row1 col4" >0.8285</td>
#       <td id="T_a7011_row1_col5" class="data row1 col5" >0.5486</td>
#       <td id="T_a7011_row1_col6" class="data row1 col6" >0.5563</td>
#     </tr>
#     <tr>
#       <th id="T_a7011_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a7011_row2_col0" class="data row2 col0" >0.7604</td>
#       <td id="T_a7011_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_a7011_row2_col2" class="data row2 col2" >0.8839</td>
#       <td id="T_a7011_row2_col3" class="data row2 col3" >0.7500</td>
#       <td id="T_a7011_row2_col4" class="data row2 col4" >0.8115</td>
#       <td id="T_a7011_row2_col5" class="data row2 col5" >0.4889</td>
#       <td id="T_a7011_row2_col6" class="data row2 col6" >0.5014</td>
#     </tr>
#     <tr>
#       <th id="T_a7011_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a7011_row3_col0" class="data row3 col0" >0.7344</td>
#       <td id="T_a7011_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_a7011_row3_col2" class="data row3 col2" >0.8571</td>
#       <td id="T_a7011_row3_col3" class="data row3 col3" >0.7328</td>
#       <td id="T_a7011_row3_col4" class="data row3 col4" >0.7901</td>
#       <td id="T_a7011_row3_col5" class="data row3 col5" >0.4344</td>
#       <td id="T_a7011_row3_col6" class="data row3 col6" >0.4444</td>
#     </tr>
#     <tr>
#       <th id="T_a7011_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a7011_row4_col0" class="data row4 col0" >0.7644</td>
#       <td id="T_a7011_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_a7011_row4_col2" class="data row4 col2" >0.8571</td>
#       <td id="T_a7011_row4_col3" class="data row4 col3" >0.7680</td>
#       <td id="T_a7011_row4_col4" class="data row4 col4" >0.8101</td>
#       <td id="T_a7011_row4_col5" class="data row4 col5" >0.5022</td>
#       <td id="T_a7011_row4_col6" class="data row4 col6" >0.5075</td>
#     </tr>
#     <tr>
#       <th id="T_a7011_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a7011_row5_col0" class="data row5 col0" >0.8377</td>
#       <td id="T_a7011_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_a7011_row5_col2" class="data row5 col2" >0.9196</td>
#       <td id="T_a7011_row5_col3" class="data row5 col3" >0.8240</td>
#       <td id="T_a7011_row5_col4" class="data row5 col4" >0.8692</td>
#       <td id="T_a7011_row5_col5" class="data row5 col5" >0.6571</td>
#       <td id="T_a7011_row5_col6" class="data row5 col6" >0.6640</td>
#     </tr>
#     <tr>
#       <th id="T_a7011_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a7011_row6_col0" class="data row6 col0" >0.8063</td>
#       <td id="T_a7011_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_a7011_row6_col2" class="data row6 col2" >0.8304</td>
#       <td id="T_a7011_row6_col3" class="data row6 col3" >0.8378</td>
#       <td id="T_a7011_row6_col4" class="data row6 col4" >0.8341</td>
#       <td id="T_a7011_row6_col5" class="data row6 col5" >0.6014</td>
#       <td id="T_a7011_row6_col6" class="data row6 col6" >0.6014</td>
#     </tr>
#     <tr>
#       <th id="T_a7011_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a7011_row7_col0" class="data row7 col0" >0.8743</td>
#       <td id="T_a7011_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_a7011_row7_col2" class="data row7 col2" >0.9369</td>
#       <td id="T_a7011_row7_col3" class="data row7 col3" >0.8595</td>
#       <td id="T_a7011_row7_col4" class="data row7 col4" >0.8966</td>
#       <td id="T_a7011_row7_col5" class="data row7 col5" >0.7373</td>
#       <td id="T_a7011_row7_col6" class="data row7 col6" >0.7418</td>
#     </tr>
#     <tr>
#       <th id="T_a7011_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a7011_row8_col0" class="data row8 col0" >0.8482</td>
#       <td id="T_a7011_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_a7011_row8_col2" class="data row8 col2" >0.8739</td>
#       <td id="T_a7011_row8_col3" class="data row8 col3" >0.8661</td>
#       <td id="T_a7011_row8_col4" class="data row8 col4" >0.8700</td>
#       <td id="T_a7011_row8_col5" class="data row8 col5" >0.6876</td>
#       <td id="T_a7011_row8_col6" class="data row8 col6" >0.6876</td>
#     </tr>
#     <tr>
#       <th id="T_a7011_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a7011_row9_col0" class="data row9 col0" >0.8429</td>
#       <td id="T_a7011_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_a7011_row9_col2" class="data row9 col2" >0.8468</td>
#       <td id="T_a7011_row9_col3" class="data row9 col3" >0.8785</td>
#       <td id="T_a7011_row9_col4" class="data row9 col4" >0.8624</td>
#       <td id="T_a7011_row9_col5" class="data row9 col5" >0.6796</td>
#       <td id="T_a7011_row9_col6" class="data row9 col6" >0.6802</td>
#     </tr>
#     <tr>
#       <th id="T_a7011_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a7011_row10_col0" class="data row10 col0" >0.8099</td>
#       <td id="T_a7011_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_a7011_row10_col2" class="data row10 col2" >0.8809</td>
#       <td id="T_a7011_row10_col3" class="data row10 col3" >0.8127</td>
#       <td id="T_a7011_row10_col4" class="data row10 col4" >0.8445</td>
#       <td id="T_a7011_row10_col5" class="data row10 col5" >0.6009</td>
#       <td id="T_a7011_row10_col6" class="data row10 col6" >0.6062</td>
#     </tr>
#     <tr>
#       <th id="T_a7011_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a7011_row11_col0" class="data row11 col0" >0.0441</td>
#       <td id="T_a7011_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_a7011_row11_col2" class="data row11 col2" >0.0332</td>
#       <td id="T_a7011_row11_col3" class="data row11 col3" >0.0488</td>
#       <td id="T_a7011_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# predict on the test set
pred_holdout = predict_model(best, data=glpn["test"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_ae79f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae79f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ae79f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ae79f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ae79f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ae79f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ae79f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ae79f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ae79f_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae79f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae79f_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_ae79f_row0_col1" class="data row0 col1" >0.7861</td>
#       <td id="T_ae79f_row0_col2" class="data row0 col2" >0.7675</td>
#       <td id="T_ae79f_row0_col3" class="data row0 col3" >0.8576</td>
#       <td id="T_ae79f_row0_col4" class="data row0 col4" >0.8017</td>
#       <td id="T_ae79f_row0_col5" class="data row0 col5" >0.8287</td>
#       <td id="T_ae79f_row0_col6" class="data row0 col6" >0.5449</td>
#       <td id="T_ae79f_row0_col7" class="data row0 col7" >0.5471</td>
#     </tr>
#   </tbody>
# </table>

# %%
# predict on the test.time set
pred_holdout = predict_model(best, data=glpn["test.time"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_93945">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93945_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_93945_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_93945_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_93945_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_93945_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_93945_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_93945_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_93945_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93945_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_93945_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_93945_row0_col1" class="data row0 col1" >0.7314</td>
#       <td id="T_93945_row0_col2" class="data row0 col2" >0.7208</td>
#       <td id="T_93945_row0_col3" class="data row0 col3" >0.7458</td>
#       <td id="T_93945_row0_col4" class="data row0 col4" >0.8581</td>
#       <td id="T_93945_row0_col5" class="data row0 col5" >0.7980</td>
#       <td id="T_93945_row0_col6" class="data row0 col6" >0.4030</td>
#       <td id="T_93945_row0_col7" class="data row0 col7" >0.4119</td>
#     </tr>
#   </tbody>
# </table>

# %%
# predict on the test.loc set
pred_holdout = predict_model(best, data=glpn["test.loc"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_db3eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db3eb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_db3eb_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_db3eb_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_db3eb_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_db3eb_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_db3eb_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_db3eb_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_db3eb_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db3eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db3eb_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_db3eb_row0_col1" class="data row0 col1" >0.6660</td>
#       <td id="T_db3eb_row0_col2" class="data row0 col2" >0.7134</td>
#       <td id="T_db3eb_row0_col3" class="data row0 col3" >0.7889</td>
#       <td id="T_db3eb_row0_col4" class="data row0 col4" >0.3318</td>
#       <td id="T_db3eb_row0_col5" class="data row0 col5" >0.4671</td>
#       <td id="T_db3eb_row0_col6" class="data row0 col6" >0.2786</td>
#       <td id="T_db3eb_row0_col7" class="data row0 col7" >0.3342</td>
#     </tr>
#   </tbody>
# </table>

# %%
save_model(best, "pycaret_glpn")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=/var/folders/6v/w9nn6c_n4qdbrjwfnq7695n00000gn/T/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None, include=[],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecated'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None, incl...
#                                                                strategy='most_frequent',
#                                                                verbose='deprecated'))),
#                  ('text_embedding',
#                   TransformerWrapper(exclude=None, include=['excerpt'],
#                                      transformer=EmbedTextFeatures(method='tf-idf'))),
#                  ('trained_model',
#                   RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True,
#                                   fit_intercept=True, max_iter=None,
#                                   normalize='deprecated', positive=False,
#                                   random_state=6370, solver='auto',
#                                   tol=0.001))],
#           verbose=False),
#  'pycaret_glpn.pkl')
